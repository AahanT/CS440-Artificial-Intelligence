# %% [markdown]
# # CS440/ECE448 Spring 2023
# # MP07: First-Order Logic, Unification, and Backward-Chaining

# %% [markdown]
# The first thing you need to do is to download this file: <a href="mp07.zip">mp07.zip</a>.  It has the following content:
#
# * `submitted.py`: Your homework. Edit, and then submit to <a href="https://www.gradescope.com/courses/486387">Gradescope</a>.
# * `mp07_notebook.ipynb`: This is a <a href="https://anaconda.org/anaconda/jupyter">Jupyter</a> notebook to help you debug.  You can completely ignore it if you want, although you might find that it gives you useful instructions.
# * `grade.py`: Once your homework seems to be working, you can test it by typing `python grade.py`, which will run the tests in `tests/tests_visible.py`.
# * `tests/test_visible.py`: This file contains about half of the <a href="https://docs.python.org/3/library/unittest.html">unit tests</a> that Gradescope will run in order to grade your homework.  If you can get a perfect score on these tests, then you should also get a perfect score on the additional hidden tests that Gradescope uses.
# * `data`: This directory contains the data.
# * `reader.py`: This is an auxiliary program that you can use to read the data.
# * `requirements.txt`: This tells you which python packages you need to have installed, in order to run `grade.py`.  You can install all of those packages by typing `pip install -r requirements.txt` or `pip3 install -r requirements.txt`.

# %% [markdown]
# This file (`mp07_notebook.ipynb`) will walk you through the whole MP, giving you instructions and debugging tips as you go.
#
# ### Table of Contents
#
# 1. <a href="#section1">Reading the data</a>
# 1. <a href="#section2">Standardize Variables</a>
# 1. <a href="#section3">Unification</a>
# 1. <a href="#section4">Rule Application</a>
# 1. <a href="#section5">Backward Chaining</a>
# 1. <a href="#grade">Grade Your Homework</a>

# %% [markdown]
# <a id='section1'></a>

# %% [markdown]
# ## Reading the data

# %% [markdown]
# There are two types of data: visible data (provided to you), and hidden data (available only to the autograder on Gradescope).  If you get your code working for the visible data, it should also work for the hidden data.
#
# The data for this MP are a set of <a href="https://allenai.org/data/ruletaker">closed-world reasoning environments</a> that were developed for the 2020 paper <a href="https://arxiv.org/abs/2002.05867">Transformers as Soft Reasoners over Language</a> by Clark, Tafjord and Richardson.  Each world includes a set of facts, and a set of questions that can be asked on the basis of those facts.
#
# In order to help you load the data, we provide you with a utility function called `reader.py`.  Since its methods are correctly documented by <a href="https://en.wikipedia.org/wiki/Docstring">docstrings</a>, you can find information about each function by using `help`:

# %%
import reader, importlib
importlib.reload(reader)
help(reader)
# Out:
# Help on module reader:
#
# NAME
#     reader
#
# DESCRIPTION
#     Read in reasoning environments from one of the RuleTaker metadata jsonl files
#     distributed by https://allenai.org/data/ruletaker.
#
# FUNCTIONS
#     load_datafile(filename)
#         Load a RuleTaker jsonl file in a format suitable for forward-chaining.
#
#         @param filename (str): the file containing the data.  Must be in jsonl format.
#
#         @return worlds (dict): a dict mapping world IDs to worlds
#           Each world is a dict containing two entries:
#           world['rules'] - a dict mapping rule IDs to rules.
#             Each rule is a dict:
#             rule['text'] is the natural language text of the rule
#             rule['antecedents'] contains the rule antecedents (a list of propositions)
#             rule['consequent'] contains the rule consequent (a proposition).
#           world['questions'] - a dict mapping question IDs to questions.
#             Each question is a dict:
#             question['text'] is the natural language text of the question
#             question['proofs'] is a string specifying the reference proof of the provided answer
#             question['query'] is a list specifying the rule in standard proposition format
#             question['answer'] indicates the correct answer, which may be one of:
#                True: query is true
#                False: query is false
#                "NAF": supported by a negative statement which wasn't disproven
#                "CWA": search for a proof exceeded maximum depth
#           Standard proposition format is a list of length 4: [head, predicate, tail, negation]
#             where negation is True or False.
#
#     parse_rule(s)
#         Parse the representation of a rule or rule
#
#         @param s (str) - string of the form ((ante1, ante2, ...) -> cons)
#            where ante1, ... and cons are all strings representing logical triples
#
#         @return antecedents (list) - list of antecedent propositions
#         @return consequent (list) - consequent proposition
#            where each proposition is a list of the form [ head, predicate, tail, negation ]
#
#     parse_triple(s)
#         Parse the representation of a logical triple.
#
#         @param s (str) - a string of the form '("head" "predicate" "tail" "negation")'
#
#         @return t (list) - a proposition, a list of the form [head, predicate, tail, negation]
#
# FILE
#     /Users/aahanthapliyal/Desktop/CS440/mp07/reader.py

# %% [markdown]
# Well, that's pretty straightforward.   Let's use it to load the `data` directory.

# %%
importlib.reload(reader)
data_worlds = reader.load_datafile('data/meta-train.jsonl')

# %%
print("There were",len(data_worlds),"logical worlds loaded.")
ids = list(data_worlds.keys())
print("Some of the world IDs are:",ids[:5])
for Ids in data_worlds:
    for rule in data_worlds[Ids]['rules']:
        if len(data_worlds[Ids]['rules'][rule]['consequent']) != 0:
            print(data_worlds[Ids]['rules'][rule]['consequent'])
# Out:
# There were 6314 logical worlds loaded.
# Some of the world IDs are: ['RelNeg-D2-1742', 'RelNoneg-D2-2133', 'AttNoneg-D2-163', 'RelNoneg-D2-820', 'RelNoneg-D2-1342']
# ['bald eagle', 'is', 'nice', True]
# ['squirrel', 'visits', 'bald eagle', True]
# ['something', 'visits', 'bald eagle', True]
# ['squirrel', 'eats', 'bald eagle', True]
# ['something', 'is', 'rough', True]
# ['something', 'needs', 'squirrel', False]
# ['squirrel', 'needs', 'bald eagle', True]
# ['bald eagle', 'visits', 'squirrel', True]
# ['bald eagle', 'needs', 'squirrel', True]
# ['squirrel', 'needs', 'bald eagle', True]
# ['bald eagle', 'eats', 'tiger', True]
# ['bald eagle', 'is', 'blue', True]
# ['bald eagle', 'is', 'green', True]
# ['bald eagle', 'is', 'kind', True]
# ['bald eagle', 'is', 'rough', True]
# ['bald eagle', 'sees', 'tiger', True]
# ['bald eagle', 'visits', 'tiger', True]
# ['tiger', 'eats', 'bald eagle', True]
# ['tiger', 'is', 'blue', True]
# ['tiger', 'is', 'green', True]
# ['tiger', 'is', 'kind', True]
# ['tiger', 'is', 'rough', True]
# ['tiger', 'is', 'young', True]
# ['tiger', 'sees', 'bald eagle', True]
# ['tiger', 'visits', 'bald eagle', True]
# ['something', 'sees', 'tiger', True]
# ['something', 'eats', 'tiger', True]
# ['something', 'eats', 'tiger', True]
# ['Anne', 'is', 'cold', True]
# ['Anne', 'is', 'red', True]
# ['Anne', 'is', 'round', True]
# ['Charlie', 'is', 'nice', True]
# ['Charlie', 'is', 'red', True]
# ['Dave', 'is', 'quiet', True]
# ['Dave', 'is', 'red', True]
# ['Dave', 'is', 'white', True]
# ['Fiona', 'is', 'kind', True]
# ['Fiona', 'is', 'quiet', True]
# ['Fiona', 'is', 'red', True]
# ['Fiona', 'is', 'white', True]
# ['Fiona', 'is', 'round', True]
# ['something', 'is', 'nice', True]
# ['bald eagle', 'eats', 'rabbit', True]
# ['lion', 'is', 'green', True]
# ['mouse', 'is', 'rough', True]
# ['rabbit', 'eats', 'mouse', True]
# ['rabbit', 'visits', 'bald eagle', True]
# ['bald eagle', 'visits', 'rabbit', True]
# ['mouse', 'needs', 'bald eagle', True]
# ['bald eagle', 'eats', 'dog', True]
# ['bald eagle', 'is', 'blue', True]
# ['bald eagle', 'needs', 'tiger', True]
# ['dog', 'eats', 'bald eagle', True]
# ['dog', 'is', 'young', True]
# ['tiger', 'eats', 'bald eagle', True]
# ['tiger', 'eats', 'dog', True]
# ['tiger', 'needs', 'bald eagle', True]
# ['tiger', 'needs', 'dog', True]
# ['tiger', 'sees', 'dog', True]
# ['dog', 'needs', 'tiger', True]
# ['bald eagle', 'eats', 'dog', True]
# ['something', 'sees', 'tiger', True]
# ['tiger', 'needs', 'bald eagle', True]
# ['something', 'eats', 'tiger', True]
# ['something', 'needs', 'dog', True]
# ['dog', 'needs', 'tiger', True]
# ['bald eagle', 'sees', 'tiger', True]
# ['Charlie', 'is', 'blue', True]
# ['Fiona', 'is', 'big', True]
# ['Gary', 'is', 'nice', True]
# ['Harry', 'is', 'big', True]
# ['Harry', 'is', 'nice', True]
# ['Harry', 'is', 'rough', True]
# ['Harry', 'is', 'white', True]
# ['someone', 'is', 'young', True]
# ['someone', 'is', 'kind', True]
# ['someone', 'is', 'blue', True]
# ['someone', 'is', 'blue', True]
# ['someone', 'is', 'white', True]
# ['someone', 'is', 'kind', True]
# ['cow', 'chases', 'rabbit', True]
# ['cow', 'is', 'red', True]
# ['cow', 'is', 'round', True]
# ['cow', 'needs', 'lion', True]
# ['cow', 'sees', 'lion', True]
# ['lion', 'chases', 'cow', True]
# ['lion', 'chases', 'rabbit', True]
# ['lion', 'is', 'cold', True]
# ['lion', 'sees', 'cow', False]
# ['rabbit', 'chases', 'lion', False]
# ['rabbit', 'needs', 'lion', True]
# ['rabbit', 'sees', 'lion', False]
# ['something', 'needs', 'cow', True]
# ['something', 'is', 'red', True]
# ['bear', 'likes', 'dog', True]
# ['dog', 'is', 'nice', True]
# ['dog', 'likes', 'bear', True]
# ['someone', 'likes', 'dog', True]
# ['someone', 'is', 'rough', True]
# ['someone', 'likes', 'bear', False]
# ['dog', 'is', 'young', True]
# ['something', 'is', 'red', False]
# ['something', 'is', 'red', False]
# ['dog', 'is', 'red', False]
# ['dog', 'is', 'nice', True]
# ['something', 'is', 'young', True]
# ['something', 'is', 'kind', False]
# ['something', 'is', 'young', True]
# ['something', 'is', 'kind', False]
# ['bear', 'chases', 'cow', True]
# ['bear', 'eats', 'rabbit', True]
# ['bear', 'sees', 'cow', True]
# ['cow', 'chases', 'rabbit', True]
# ['cow', 'sees', 'bear', True]
# ['cow', 'sees', 'rabbit', True]
# ['dog', 'is', 'blue', True]
# ['dog', 'sees', 'cow', True]
# ['rabbit', 'chases', 'bear', True]
# ['rabbit', 'chases', 'dog', True]
# ['rabbit', 'eats', 'cow', True]
# ['rabbit', 'is', 'young', True]
# ['something', 'chases', 'bear', True]
# ['rabbit', 'eats', 'dog', True]
# ['dog', 'sees', 'bear', True]
# ['Anne', 'is', 'smart', True]
# ['Charlie', 'is', 'rough', True]
# ['Erin', 'is', 'nice', True]
# ['something', 'is', 'red', False]
# ['something', 'is', 'green', True]
# ['something', 'is', 'nice', True]
# ['bear', 'chases', 'dog', True]
# ['dog', 'is', 'blue', True]
# ['lion', 'visits', 'dog', True]
# ['someone', 'visits', 'bear', True]
# ['lion', 'needs', 'dog', True]
# ['lion', 'visits', 'dog', True]
# ['someone', 'visits', 'bear', True]
# ['bear', 'visits', 'dog', True]
# ['lion', 'chases', 'dog', True]
# ['Charlie', 'is', 'quiet', True]
# ['Dave', 'is', 'furry', True]
# ['Fiona', 'is', 'green', True]
# ['Fiona', 'is', 'red', True]
# ['Fiona', 'is', 'rough', False]
# ['Gary', 'is', 'green', True]
# ['Gary', 'is', 'kind', True]
# ['Fiona', 'is', 'young', True]
# ['something', 'is', 'red', True]
# ['something', 'is', 'furry', True]
# ['something', 'is', 'quiet', True]
# ['something', 'is', 'furry', True]
# ['something', 'is', 'furry', True]
# ['Anne', 'is', 'cold', False]
# ['Bob', 'is', 'cold', True]
# ['Bob', 'is', 'round', False]
# ['Dave', 'is', 'blue', True]
# ['Dave', 'is', 'nice', True]
# ['Fiona', 'is', 'round', True]
# ['Fiona', 'is', 'young', True]
# ['something', 'is', 'cold', True]
# ['something', 'is', 'big', True]
# ['something', 'is', 'big', True]
# ['bald eagle', 'eats', 'lion', True]
# ['bald eagle', 'is', 'nice', True]
# ['bald eagle', 'is', 'young', False]
# ['bald eagle', 'visits', 'lion', True]
# ['cat', 'chases', 'lion', True]
# ['cat', 'chases', 'squirrel', True]
# ['cat', 'eats', 'lion', True]
# ['cat', 'is', 'rough', True]
# ['cat', 'is', 'round', True]
# ['lion', 'chases', 'bald eagle', True]
# ['lion', 'chases', 'squirrel', False]
# ['lion', 'is', 'rough', True]
# ['squirrel', 'eats', 'bald eagle', True]
# ['squirrel', 'eats', 'lion', True]
# ['squirrel', 'is', 'nice', False]
# ['cat', 'visits', 'lion', True]
# ['bald eagle', 'visits', 'lion', True]
# ['squirrel', 'is', 'round', False]
# ['something', 'chases', 'bald eagle', True]
# ['cat', 'eats', 'bald eagle', True]
# ['lion', 'chases', 'cat', True]
# ['something', 'eats', 'lion', True]
# ['lion', 'chases', 'cat', True]
# ['bald eagle', 'is', 'cold', True]
# ['bald eagle', 'is', 'kind', True]
# ['bald eagle', 'is', 'red', True]
# ['bald eagle', 'is', 'round', True]
# ['bald eagle', 'is', 'young', True]
# ['bald eagle', 'likes', 'tiger', True]
# ['bald eagle', 'needs', 'tiger', True]
# ['bald eagle', 'visits', 'tiger', True]
# ['tiger', 'is', 'cold', True]
# ['tiger', 'is', 'kind', True]
# ['tiger', 'is', 'red', True]
# ['tiger', 'is', 'round', True]
# ['tiger', 'is', 'young', True]
# ['tiger', 'likes', 'bald eagle', True]
# ['tiger', 'needs', 'bald eagle', True]
# ['tiger', 'visits', 'bald eagle', True]
# ['something', 'visits', 'bald eagle', True]
# ['something', 'needs', 'bald eagle', True]
# ['Charlie', 'is', 'blue', True]
# ['Charlie', 'is', 'kind', True]
# ['Charlie', 'is', 'nice', True]
# ['Charlie', 'is', 'quiet', True]
# ['Charlie', 'is', 'rough', True]
# ['Dave', 'is', 'blue', True]
# ['Dave', 'is', 'rough', True]
# ['Gary', 'is', 'kind', True]
# ['Gary', 'is', 'nice', True]
# ['Gary', 'is', 'red', True]
# ['Harry', 'is', 'blue', True]
# ['Harry', 'is', 'kind', True]
# ['Harry', 'is', 'nice', True]
# ['Harry', 'is', 'quiet', True]
# ['Harry', 'is', 'red', True]
# ['Harry', 'is', 'rough', True]
# ['something', 'is', 'white', True]
# ['something', 'is', 'quiet', True]
# ['Charlie', 'is', 'blue', True]
# ['something', 'is', 'blue', True]
# ['something', 'is', 'white', True]
# ['something', 'is', 'quiet', True]
# ['something', 'is', 'kind', True]
# ['something', 'is', 'white', True]
# ['Anne', 'is', 'blue', True]
# ['Anne', 'is', 'cold', True]
# ['Anne', 'is', 'furry', True]
# ['Anne', 'is', 'green', True]
# ['Anne', 'is', 'kind', True]
# ['Anne', 'is', 'nice', False]
# ['Anne', 'is', 'round', True]
# ['Charlie', 'is', 'green', True]
# ['Charlie', 'is', 'kind', True]
# ['Charlie', 'is', 'nice', True]
# ['Charlie', 'is', 'round', True]
# ['Erin', 'is', 'blue', True]
# ['Erin', 'is', 'cold', True]
# ['Erin', 'is', 'furry', False]
# ['Erin', 'is', 'kind', False]
# ['Erin', 'is', 'nice', True]
# ['something', 'is', 'round', True]
# ['something', 'is', 'cold', True]
# ['something', 'is', 'blue', True]
# ['dog', 'is', 'young', True]
# ['dog', 'likes', 'lion', True]
# ['dog', 'needs', 'lion', True]
# ['dog', 'visits', 'lion', True]
# ['lion', 'is', 'big', True]
# ['lion', 'is', 'rough', True]
# ['lion', 'is', 'young', True]
# ['lion', 'likes', 'dog', True]
# ['lion', 'needs', 'dog', True]
# ['lion', 'visits', 'dog', True]
# ['someone', 'is', 'rough', True]
# ['someone', 'is', 'big', True]
# ['mouse', 'is', 'kind', True]
# ['rabbit', 'needs', 'mouse', True]
# ['rabbit', 'is', 'cold', True]
# ['something', 'chases', 'mouse', True]
# ['mouse', 'sees', 'rabbit', True]
# ['Bob', 'is', 'blue', True]
# ['Bob', 'is', 'kind', True]
# ['Bob', 'is', 'quiet', True]
# ['Dave', 'is', 'red', True]
# ['Dave', 'is', 'rough', True]
# ['Dave', 'is', 'round', True]
# ['Dave', 'is', 'young', True]
# ['something', 'is', 'round', True]
# ['something', 'is', 'kind', True]
# ['something', 'is', 'blue', True]
# ['something', 'is', 'round', True]
# ['something', 'is', 'round', True]
# ['something', 'is', 'rough', True]
# ['Anne', 'is', 'green', True]
# ['Anne', 'is', 'smart', True]
# ['Charlie', 'is', 'young', True]
# ['something', 'is', 'young', True]
# ['something', 'is', 'young', True]
# ['Anne', 'is', 'quiet', True]
# ['cow', 'is', 'young', True]
# ['dog', 'chases', 'cow', False]
# ['dog', 'chases', 'lion', True]
# ['dog', 'chases', 'tiger', False]
# ['dog', 'eats', 'cow', True]
# ['dog', 'is', 'green', True]
# ['dog', 'needs', 'lion', True]
# ['lion', 'eats', 'cow', True]
# ['tiger', 'chases', 'dog', True]
# ['tiger', 'chases', 'lion', True]
# ['tiger', 'eats', 'lion', True]
# ['tiger', 'is', 'rough', True]
# ['tiger', 'is', 'round', False]
# ['tiger', 'needs', 'cow', False]
# ['tiger', 'needs', 'dog', False]
# ['tiger', 'needs', 'lion', True]
# ['dog', 'needs', 'cow', True]
# ['something', 'eats', 'lion', True]
# ['something', 'is', 'round', True]
# ['cow', 'sees', 'lion', True]
# ['lion', 'needs', 'cow', True]
# ['someone', 'needs', 'lion', False]
# ['cow', 'is', 'blue', True]
# ['lion', 'is', 'red', True]
# ['bald eagle', 'sees', 'lion', True]
# ['lion', 'chases', 'tiger', True]
# ['tiger', 'likes', 'lion', True]
# ['someone', 'sees', 'bald eagle', True]
# ['bald eagle', 'sees', 'lion', True]
# ['bald eagle', 'chases', 'lion', True]
# ['tiger', 'chases', 'lion', True]
# ['tiger', 'is', 'kind', True]
# ['someone', 'is', 'kind', True]
# ['tiger', 'likes', 'lion', False]
# ['someone', 'is', 'young', True]
# ['bald eagle', 'is', 'big', True]
# ['bald eagle', 'sees', 'tiger', True]
# ['bald eagle', 'visits', 'tiger', True]
# ['tiger', 'is', 'big', True]
# ['tiger', 'is', 'round', True]
# ['tiger', 'sees', 'bald eagle', False]
# ['tiger', 'visits', 'bald eagle', False]
# ['bald eagle', 'eats', 'tiger', True]
# ['bald eagle', 'is', 'young', True]
# ['someone', 'visits', 'tiger', True]
# ['tiger', 'is', 'nice', True]
# ['bald eagle', 'eats', 'tiger', True]
# ['someone', 'is', 'cold', False]
# ['someone', 'eats', 'tiger', True]
# ['bald eagle', 'is', 'cold', False]
# ['Charlie', 'is', 'quiet', True]
# ['Fiona', 'is', 'big', True]
# ['Fiona', 'is', 'furry', True]
# ['Fiona', 'is', 'quiet', True]
# ['Fiona', 'is', 'red', True]
# ['Fiona', 'is', 'round', True]
# ['Fiona', 'is', 'smart', True]
# ['Charlie', 'is', 'red', True]
# ['something', 'is', 'quiet', True]
# ['something', 'is', 'furry', True]
# ['something', 'is', 'smart', True]
# ['something', 'is', 'round', True]
# ['something', 'is', 'red', True]
# ['Dave', 'is', 'young', True]
# ['something', 'is', 'furry', False]
# ['something', 'is', 'furry', True]
# ['Dave', 'is', 'furry', False]
# ['something', 'is', 'quiet', True]
# ['something', 'is', 'big', True]
# ['Dave', 'is', 'big', False]
# ['something', 'is', 'green', False]
# ['something', 'is', 'green', False]
# ['Charlie', 'is', 'nice', True]
# ['Charlie', 'is', 'smart', True]
# ['Erin', 'is', 'furry', True]
# ['Erin', 'is', 'kind', False]
# ['Erin', 'is', 'red', True]
# ['Erin', 'is', 'smart', True]
# ['Erin', 'is', 'white', False]
# ['Fiona', 'is', 'kind', True]
# ['Fiona', 'is', 'nice', True]
# ['Fiona', 'is', 'red', True]
# ['Fiona', 'is', 'round', True]
# ['Fiona', 'is', 'white', True]
# ['someone', 'is', 'nice', True]
# ['someone', 'is', 'round', True]
# ['Dave', 'is', 'furry', True]
# ['Dave', 'is', 'nice', True]
# ['Erin', 'is', 'cold', True]
# ['Erin', 'is', 'nice', True]
# ['something', 'is', 'furry', True]
# ['something', 'is', 'round', True]
# ['Dave', 'is', 'big', True]
# ['something', 'is', 'blue', True]
# ['something', 'is', 'furry', True]
# ['something', 'is', 'big', True]
# ['something', 'is', 'round', True]
# ['cow', 'eats', 'mouse', True]
# ['cow', 'is', 'big', True]
# ['cow', 'is', 'blue', True]
# ['cow', 'is', 'cold', True]
# ['cow', 'is', 'green', True]
# ['cow', 'is', 'rough', True]
# ['cow', 'sees', 'mouse', True]
# ['cow', 'visits', 'mouse', True]
# ['mouse', 'eats', 'cow', True]
# ['mouse', 'is', 'big', True]
# ['mouse', 'is', 'blue', True]
# ['mouse', 'is', 'cold', True]
# ['mouse', 'is', 'green', True]
# ['mouse', 'sees', 'cow', True]
# ['mouse', 'visits', 'cow', True]
# ['something', 'is', 'blue', True]
# ['something', 'eats', 'cow', True]
# ['cow', 'is', 'green', True]
# ['cow', 'sees', 'mouse', True]
# ['something', 'visits', 'cow', True]
# ['something', 'visits', 'mouse', True]
# ['Anne', 'is', 'round', True]
# ['something', 'is', 'round', True]
# ['Anne', 'is', 'kind', True]
# ['something', 'is', 'kind', True]
# ['Anne', 'is', 'white', True]
# ['something', 'is', 'round', True]
# ['something', 'is', 'furry', True]
# ['mouse', 'eats', 'rabbit', True]
# ['mouse', 'is', 'green', True]
# ['mouse', 'is', 'kind', True]
# ['mouse', 'needs', 'rabbit', True]
# ['mouse', 'visits', 'rabbit', True]
# ['rabbit', 'eats', 'mouse', True]
# ['rabbit', 'is', 'green', True]
# ['rabbit', 'is', 'kind', True]
# ['rabbit', 'is', 'round', True]
# ['rabbit', 'is', 'young', True]
# ['rabbit', 'needs', 'mouse', True]
# ['rabbit', 'visits', 'mouse', True]
# ['someone', 'is', 'blue', True]
# ['someone', 'visits', 'rabbit', True]
# ['rabbit', 'needs', 'mouse', True]
# ['someone', 'needs', 'mouse', True]
# ['someone', 'is', 'green', True]
# ['someone', 'eats', 'rabbit', True]
# ['someone', 'needs', 'rabbit', True]
# ['mouse', 'visits', 'rabbit', True]
# ['Bob', 'is', 'blue', True]
# ['Bob', 'is', 'furry', True]
# ['Bob', 'is', 'red', True]
# ['Fiona', 'is', 'blue', True]
# ['Fiona', 'is', 'cold', True]
# ['Fiona', 'is', 'quiet', True]
# ['Fiona', 'is', 'red', True]
# ['Fiona', 'is', 'rough', True]
# ['Harry', 'is', 'big', True]
# ['Harry', 'is', 'blue', True]
# ['Harry', 'is', 'cold', True]
# ['Harry', 'is', 'furry', True]
# ['Harry', 'is', 'quiet', True]
# ['Harry', 'is', 'red', True]
# ['Harry', 'is', 'rough', True]
# ['something', 'is', 'quiet', True]
# ['something', 'is', 'big', True]
# ['something', 'is', 'red', True]
# ['something', 'is', 'big', True]
# ['something', 'is', 'furry', True]
# ['something', 'is', 'furry', True]
# ['something', 'is', 'blue', True]
# ['something', 'is', 'red', True]
# ['Harry', 'is', 'cold', True]
# ['Harry', 'is', 'nice', True]
# ['Harry', 'is', 'smart', True]
# ['someone', 'is', 'green', True]
# ['someone', 'is', 'blue', True]
# ['someone', 'is', 'white', False]
# ['someone', 'is', 'kind', True]
# ['someone', 'is', 'nice', True]
# ['Harry', 'is', 'green', True]
# ['Harry', 'is', 'cold', True]
# ['Harry', 'is', 'nice', True]
# ['Erin', 'is', 'red', True]
# ['Gary', 'is', 'blue', True]
# ['Gary', 'is', 'white', True]
# ['something', 'is', 'quiet', True]
# ['something', 'is', 'red', True]
# ['something', 'is', 'quiet', True]
# ['something', 'is', 'blue', True]
# ['something', 'is', 'rough', True]
# ['something', 'is', 'nice', True]
# ['something', 'is', 'quiet', True]
# ['something', 'is', 'cold', True]
# ['mouse', 'is', 'cold', True]
# ['mouse', 'is', 'green', True]
# ['mouse', 'is', 'red', True]
# ['mouse', 'is', 'rough', True]
# ['mouse', 'is', 'young', True]
# ['mouse', 'likes', 'squirrel', True]
# ['mouse', 'sees', 'squirrel', True]
# ['mouse', 'visits', 'squirrel', True]
# ['squirrel', 'is', 'cold', True]
# ['squirrel', 'is', 'green', True]
# ['squirrel', 'is', 'red', True]
# ['squirrel', 'is', 'rough', True]
# ['squirrel', 'is', 'young', True]
# ['squirrel', 'likes', 'mouse', True]
# ['squirrel', 'sees', 'mouse', True]
# ['squirrel', 'visits', 'mouse', True]
# ['mouse', 'visits', 'squirrel', True]
# ['someone', 'sees', 'squirrel', True]
# ['someone', 'likes', 'squirrel', True]
# ['cow', 'eats', 'mouse', True]
# ['cow', 'eats', 'rabbit', True]
# ['cow', 'needs', 'rabbit', True]
# ['mouse', 'chases', 'rabbit', True]
# ['mouse', 'eats', 'cow', False]
# ['mouse', 'is', 'blue', True]
# ['mouse', 'is', 'green', True]
# ['mouse', 'needs', 'cow', True]
# ['rabbit', 'chases', 'mouse', True]
# ['rabbit', 'eats', 'cow', True]
# ['rabbit', 'is', 'blue', True]
# ['rabbit', 'is', 'green', False]
# ['rabbit', 'is', 'nice', False]
# ['rabbit', 'is', 'red', True]
# ['rabbit', 'needs', 'cow', False]
# ['rabbit', 'needs', 'mouse', True]
# ['cow', 'needs', 'mouse', True]
# ['cow', 'is', 'nice', True]
# ['someone', 'eats', 'cow', True]
# ['mouse', 'eats', 'rabbit', True]
# ['mouse', 'chases', 'cow', False]
# ['someone', 'chases', 'cow', True]
# ['mouse', 'needs', 'rabbit', True]
# ['cow', 'needs', 'rabbit', True]
# ['dog', 'likes', 'lion', True]
# ['lion', 'likes', 'tiger', True]
# ['squirrel', 'sees', 'dog', True]
# ['tiger', 'needs', 'lion', True]
# ['something', 'likes', 'tiger', True]
# ['something', 'is', 'round', True]
# ['Bob', 'is', 'nice', True]
# ['Bob', 'is', 'rough', True]
# ['Erin', 'is', 'big', True]
# ['Erin', 'is', 'cold', True]
# ['Erin', 'is', 'kind', True]
# ['Erin', 'is', 'nice', True]
# ['Erin', 'is', 'rough', True]
# ['Erin', 'is', 'young', True]
# ['someone', 'is', 'quiet', True]
# ['someone', 'is', 'kind', True]
# ['someone', 'is', 'young', True]
# ['someone', 'is', 'quiet', True]
# ['someone', 'is', 'nice', True]
# ['Charlie', 'is', 'big', True]
# ['Charlie', 'is', 'cold', True]
# ['Charlie', 'is', 'furry', False]
# ['Charlie', 'is', 'green', True]
# ['Charlie', 'is', 'red', True]
# ['Fiona', 'is', 'big', True]
# ['Fiona', 'is', 'furry', True]
# ['someone', 'is', 'blue', False]
# ['someone', 'is', 'red', False]
# ['someone', 'is', 'red', True]
# ['Anne', 'is', 'kind', True]
# ['Charlie', 'is', 'furry', True]
# ['Gary', 'is', 'big', True]
# ['Gary', 'is', 'young', True]
# ['someone', 'is', 'young', True]
# ['someone', 'is', 'big', False]
# ['someone', 'is', 'red', False]
# ['someone', 'is', 'round', True]
# ['someone', 'is', 'red', False]
# ['Harry', 'is', 'nice', True]
# ['Harry', 'is', 'round', True]
# ['Harry', 'is', 'young', True]
# ['someone', 'is', 'quiet', True]
# ['someone', 'is', 'cold', True]
# ['dog', 'eats', 'tiger', True]
# ['dog', 'is', 'cold', True]
# ['dog', 'is', 'kind', True]
# ['dog', 'is', 'nice', True]
# ['dog', 'needs', 'tiger', True]
# ['tiger', 'is', 'nice', True]
# ['tiger', 'needs', 'dog', True]
# ['dog', 'is', 'rough', True]
# ['something', 'eats', 'dog', True]
# ['dog', 'sees', 'tiger', True]
# ['cat', 'is', 'young', False]
# ['cat', 'sees', 'mouse', True]
# ['cat', 'sees', 'tiger', True]
# ['mouse', 'likes', 'tiger', True]
# ['tiger', 'chases', 'cat', True]
# ['tiger', 'chases', 'mouse', True]
# ['tiger', 'is', 'green', False]
# ['someone', 'likes', 'mouse', True]
# ['someone', 'is', 'big', False]
# ['mouse', 'sees', 'tiger', True]
# ['Anne', 'is', 'blue', True]
# ['Anne', 'is', 'cold', True]
# ['Anne', 'is', 'furry', True]
# ['Anne', 'is', 'kind', True]
# ['Anne', 'is', 'quiet', True]
# ['Anne', 'is', 'young', True]
# ['Bob', 'is', 'blue', True]
# ['Bob', 'is', 'furry', True]
# ['Bob', 'is', 'kind', True]
# ['Bob', 'is', 'quiet', True]
# ['Bob', 'is', 'round', True]
# ['Bob', 'is', 'young', True]
# ['Gary', 'is', 'blue', True]
# ['Gary', 'is', 'cold', True]
# ['Gary', 'is', 'furry', True]
# ['Gary', 'is', 'kind', True]
# ['someone', 'is', 'round', True]
# ['someone', 'is', 'young', True]
# ['someone', 'is', 'blue', True]
# ['someone', 'is', 'kind', True]
# ['someone', 'is', 'blue', True]
# ['Bob', 'is', 'quiet', True]
# ['someone', 'is', 'cold', True]
# ['someone', 'is', 'round', True]
# ['Dave', 'is', 'big', True]
# ['Dave', 'is', 'blue', True]
# ['Dave', 'is', 'rough', True]
# ['Dave', 'is', 'white', True]
# ['Fiona', 'is', 'blue', True]
# ['Fiona', 'is', 'white', True]
# ['Fiona', 'is', 'young', True]
# ['someone', 'is', 'white', True]
# ['someone', 'is', 'young', True]
# ['someone', 'is', 'furry', True]
# ['someone', 'is', 'white', True]
# ['someone', 'is', 'nice', True]
# ['someone', 'is', 'furry', True]
# ['Anne', 'is', 'kind', True]
# ['Anne', 'is', 'red', True]
# ['Anne', 'is', 'smart', True]
# ['Dave', 'is', 'furry', True]
# ['Dave', 'is', 'round', True]
# ['Fiona', 'is', 'furry', True]
# ['Fiona', 'is', 'green', True]
# ['Fiona', 'is', 'red', True]
# ['Fiona', 'is', 'round', True]
# ['Fiona', 'is', 'smart', True]
# ['Fiona', 'is', 'white', True]
# ['Gary', 'is', 'green', True]
# ['Gary', 'is', 'red', True]
# ['Gary', 'is', 'round', True]
# ['Gary', 'is', 'smart', True]
# ['someone', 'is', 'white', True]
# ['someone', 'is', 'smart', True]
# ['someone', 'is', 'green', True]
# ['Anne', 'is', 'rough', True]
# ['Anne', 'is', 'young', True]
# ['Charlie', 'is', 'nice', True]
# ['Erin', 'is', 'nice', True]
# ['Erin', 'is', 'rough', True]
# ['Erin', 'is', 'smart', True]
# ['Erin', 'is', 'young', True]
# ['Fiona', 'is', 'furry', True]
# ['Fiona', 'is', 'kind', True]
# ['Fiona', 'is', 'nice', True]
# ['Fiona', 'is', 'rough', True]
# ['Fiona', 'is', 'smart', True]
# ['someone', 'is', 'red', True]
# ['someone', 'is', 'kind', True]
# ['someone', 'is', 'smart', True]
# ['Charlie', 'is', 'cold', True]
# ['someone', 'is', 'kind', True]
# ['Charlie', 'is', 'blue', False]
# ['Charlie', 'is', 'cold', True]
# ['someone', 'is', 'round', False]
# ['someone', 'is', 'blue', True]
# ['someone', 'is', 'green', False]
# ['Charlie', 'is', 'cold', True]
# ['someone', 'is', 'cold', True]
# ['Anne', 'is', 'cold', True]
# ['Anne', 'is', 'kind', True]
# ['Anne', 'is', 'smart', True]
# ['Dave', 'is', 'smart', True]
# ['Erin', 'is', 'furry', True]
# ['Harry', 'is', 'blue', True]
# ['Harry', 'is', 'kind', True]
# ['Dave', 'is', 'kind', False]
# ['something', 'is', 'quiet', True]
# ['something', 'is', 'white', True]
# ['something', 'is', 'kind', True]
# ['Dave', 'is', 'white', True]
# ['something', 'is', 'furry', True]
# ['Anne', 'is', 'furry', True]
# ['Bob', 'is', 'big', True]
# ['Dave', 'is', 'quiet', True]
# ['something', 'is', 'kind', True]
# ['something', 'is', 'kind', True]
# ['something', 'is', 'quiet', False]
# ['Anne', 'is', 'cold', True]
# ['something', 'is', 'rough', True]
# ['something', 'is', 'smart', True]
# ['Fiona', 'is', 'cold', True]
# ['Gary', 'is', 'kind', True]
# ['someone', 'is', 'green', True]
# ['someone', 'is', 'rough', True]
# ['cow', 'chases', 'lion', True]
# ['cow', 'likes', 'lion', True]
# ['lion', 'chases', 'cow', True]
# ['lion', 'chases', 'mouse', True]
# ['lion', 'is', 'kind', True]
# ['lion', 'likes', 'mouse', True]
# ['lion', 'needs', 'cow', True]
# ['mouse', 'chases', 'cow', True]
# ['mouse', 'is', 'blue', True]
# ['mouse', 'is', 'kind', True]
# ['something', 'is', 'blue', True]
# ['lion', 'needs', 'mouse', True]
# ['mouse', 'needs', 'lion', True]
# ['something', 'likes', 'cow', True]
# ['lion', 'is', 'blue', True]
# ['something', 'is', 'red', True]
# ['dog', 'needs', 'squirrel', True]
# ['squirrel', 'is', 'round', True]
# ['squirrel', 'needs', 'dog', True]
# ['dog', 'likes', 'squirrel', True]
# ['squirrel', 'is', 'round', True]
# ['something', 'likes', 'dog', True]
# ['Anne', 'is', 'quiet', True]
# ['Bob', 'is', 'quiet', True]
# ['Dave', 'is', 'kind', True]
# ['Harry', 'is', 'rough', True]
# ['someone', 'is', 'rough', True]
# ['someone', 'is', 'round', True]
# ['Harry', 'is', 'red', True]
# ['Bob', 'is', 'furry', True]
# ['Bob', 'is', 'round', True]
# ['Bob', 'is', 'smart', True]
# ['Bob', 'is', 'white', True]
# ['Dave', 'is', 'kind', True]
# ['Dave', 'is', 'quiet', True]
# ['Dave', 'is', 'round', True]
# ['Erin', 'is', 'big', True]
# ['Erin', 'is', 'kind', True]
# ['Erin', 'is', 'round', True]
# ['Erin', 'is', 'smart', True]
# ['Harry', 'is', 'smart', True]
# ['something', 'is', 'smart', True]
# ['something', 'is', 'white', True]
# ['something', 'is', 'big', True]
# ['something', 'is', 'smart', True]
# ['something', 'is', 'quiet', True]
# ['Dave', 'is', 'kind', True]
# ['bald eagle', 'is', 'big', True]
# ['squirrel', 'eats', 'bald eagle', True]
# ['tiger', 'eats', 'bald eagle', False]
# ['squirrel', 'chases', 'bald eagle', True]
# ['squirrel', 'likes', 'tiger', False]
# ['bald eagle', 'is', 'nice', False]
# ['bald eagle', 'chases', 'squirrel', True]
# ['something', 'likes', 'tiger', False]
# ['bald eagle', 'chases', 'squirrel', True]
# ['something', 'is', 'round', True]
# ['squirrel', 'is', 'round', True]
# ['cat', 'is', 'green', True]
# ['cat', 'likes', 'cow', False]
# ['cat', 'likes', 'mouse', True]
# ['cat', 'likes', 'squirrel', True]
# ['cat', 'needs', 'squirrel', True]
# ['cow', 'is', 'red', True]
# ['cow', 'is', 'round', True]
# ['cow', 'needs', 'cat', True]
# ['cow', 'needs', 'squirrel', True]
# ['mouse', 'is', 'red', True]
# ['mouse', 'is', 'round', True]
# ['mouse', 'needs', 'cat', False]
# ['squirrel', 'is', 'green', True]
# ['squirrel', 'likes', 'cow', True]
# ['squirrel', 'needs', 'cat', False]
# ['squirrel', 'visits', 'mouse', True]
# ['something', 'likes', 'mouse', False]
# ['something', 'needs', 'squirrel', True]
# ['something', 'visits', 'mouse', False]
# ['cow', 'visits', 'squirrel', True]
# ['squirrel', 'visits', 'mouse', True]
# ['something', 'visits', 'mouse', True]
# ['mouse', 'is', 'round', True]
# ['someone', 'is', 'young', True]
# ['mouse', 'is', 'big', True]
# ['Anne', 'is', 'big', True]
# ['Anne', 'is', 'nice', True]
# ['Anne', 'is', 'quiet', True]
# ['Anne', 'is', 'smart', True]
# ['Anne', 'is', 'young', True]
# ['Dave', 'is', 'rough', True]
# ['Dave', 'is', 'young', True]
# ['Fiona', 'is', 'big', True]
# ['Fiona', 'is', 'nice', True]
# ['Fiona', 'is', 'quiet', False]
# ['Fiona', 'is', 'rough', False]
# ['Fiona', 'is', 'young', True]
# ['Gary', 'is', 'big', True]
# ['Gary', 'is', 'nice', True]
# ['Gary', 'is', 'round', True]
# ['something', 'is', 'nice', True]
# ['something', 'is', 'smart', True]
# ['something', 'is', 'smart', True]
# ['Dave', 'is', 'green', True]
# ['Dave', 'is', 'smart', True]
# ['Dave', 'is', 'young', True]
# ['Fiona', 'is', 'big', True]
# ['Fiona', 'is', 'furry', True]
# ['Fiona', 'is', 'green', True]
# ['Fiona', 'is', 'kind', True]
# ['Fiona', 'is', 'smart', True]
# ['Fiona', 'is', 'young', True]
# ['Gary', 'is', 'big', True]
# ['Gary', 'is', 'furry', True]
# ['Gary', 'is', 'green', True]
# ['Gary', 'is', 'kind', True]
# ['Gary', 'is', 'quiet', True]
# ['Gary', 'is', 'smart', True]
# ['Gary', 'is', 'young', True]
# ['something', 'is', 'furry', True]
# ['something', 'is', 'smart', True]
# ['something', 'is', 'quiet', True]
# ['Charlie', 'is', 'cold', True]
# ['someone', 'is', 'rough', True]
# ['someone', 'is', 'kind', True]
# ['someone', 'is', 'kind', False]
# ['Charlie', 'is', 'cold', True]
# ['someone', 'is', 'nice', False]
# ['someone', 'is', 'nice', False]
# ['someone', 'is', 'big', True]
# ['Charlie', 'is', 'blue', False]
# ['Charlie', 'is', 'kind', True]
# ['Charlie', 'is', 'quiet', True]
# ['Charlie', 'is', 'rough', True]
# ['Charlie', 'is', 'white', True]
# ['Erin', 'is', 'nice', False]
# ['Erin', 'is', 'white', True]
# ['Fiona', 'is', 'furry', False]
# ['Fiona', 'is', 'nice', False]
# ['Fiona', 'is', 'rough', True]
# ['Fiona', 'is', 'white', False]
# ['something', 'is', 'quiet', True]
# ['Fiona', 'is', 'smart', True]
# ['squirrel', 'is', 'green', True]
# ['someone', 'is', 'blue', True]
# ['someone', 'is', 'green', True]
# ['someone', 'is', 'red', True]
# ['someone', 'is', 'blue', True]
# ['someone', 'is', 'cold', True]
# ['someone', 'is', 'blue', True]
# ['bald eagle', 'chases', 'cow', True]
# ['bald eagle', 'needs', 'bear', True]
# ['bear', 'eats', 'bald eagle', True]
# ['bear', 'needs', 'mouse', True]
# ['cow', 'eats', 'mouse', True]
# ['cow', 'is', 'big', True]
# ['cow', 'is', 'blue', True]
# ['cow', 'is', 'kind', True]
# ['cow', 'needs', 'bear', True]
# ['cow', 'needs', 'mouse', True]
# ['mouse', 'is', 'big', True]
# ['mouse', 'needs', 'bald eagle', True]
# ['bear', 'needs', 'bald eagle', True]
# ['bear', 'is', 'big', False]
# ['mouse', 'chases', 'bald eagle', True]
# ['something', 'eats', 'bald eagle', True]
# ['something', 'eats', 'mouse', False]
# ['cow', 'chases', 'bear', True]
# ['bald eagle', 'visits', 'rabbit', True]
# ['mouse', 'is', 'nice', True]
# ['rabbit', 'eats', 'tiger', False]
# ['tiger', 'visits', 'mouse', True]
# ['something', 'is', 'cold', True]
# ['mouse', 'eats', 'bald eagle', True]
# ['mouse', 'is', 'blue', True]
# ['something', 'eats', 'bald eagle', True]
# ['something', 'visits', 'bald eagle', True]
# ['something', 'is', 'kind', False]
# ['something', 'eats', 'tiger', True]
# ['something', 'eats', 'rabbit', True]
# ['Bob', 'is', 'nice', True]
# ['Bob', 'is', 'quiet', True]
# ['Bob', 'is', 'rough', True]
# ['Bob', 'is', 'round', True]
# ['Bob', 'is', 'white', False]
# ['Bob', 'is', 'young', True]
# ['Charlie', 'is', 'white', False]
# ['Dave', 'is', 'quiet', True]
# ['Dave', 'is', 'round', False]
# ['Dave', 'is', 'young', True]
# ['Erin', 'is', 'white', True]
# ['Erin', 'is', 'young', True]
# ['something', 'is', 'nice', True]
# ['Charlie', 'is', 'rough', False]
# ['something', 'is', 'quiet', False]
# ['something', 'is', 'quiet', False]
# ['something', 'is', 'rough', True]
# ['something', 'is', 'quiet', True]
# ['something', 'is', 'cold', True]
# ['something', 'is', 'rough', True]
# ['bear', 'is', 'nice', False]
# ['bear', 'is', 'round', True]
# ['bear', 'likes', 'mouse', True]
# ['dog', 'chases', 'bear', True]
# ['dog', 'is', 'round', True]
# ['dog', 'likes', 'mouse', False]
# ['dog', 'likes', 'tiger', False]
# ['mouse', 'is', 'nice', True]
# ['mouse', 'is', 'red', True]
# ['mouse', 'likes', 'dog', True]
# ['tiger', 'is', 'nice', True]
# ['tiger', 'is', 'red', True]
# ['tiger', 'likes', 'dog', True]
# ['tiger', 'sees', 'bear', True]
# ['tiger', 'sees', 'mouse', True]
# ['someone', 'is', 'red', False]
# ['someone', 'chases', 'bear', False]
# ['tiger', 'is', 'cold', True]
# ['dog', 'likes', 'mouse', True]
# ['dog', 'chases', 'mouse', True]
# ['someone', 'sees', 'dog', False]
# ['someone', 'sees', 'tiger', True]
# ['someone', 'chases', 'mouse', True]
# ['Bob', 'is', 'cold', True]
# ['Bob', 'is', 'nice', True]
# ['Bob', 'is', 'quiet', True]
# ['Bob', 'is', 'rough', True]
# ['Bob', 'is', 'smart', True]
# ['Bob', 'is', 'white', True]
# ['Charlie', 'is', 'nice', True]
# ['Charlie', 'is', 'white', True]
# ['Fiona', 'is', 'big', True]
# ['Gary', 'is', 'cold', True]
# ['something', 'is', 'nice', True]
# ['something', 'is', 'white', True]
# ['Gary', 'is', 'big', True]
# ['Gary', 'is', 'green', True]
# ['Gary', 'is', 'quiet', True]
# ['someone', 'is', 'white', True]
# ['Gary', 'is', 'quiet', True]
# ['someone', 'is', 'green', False]
# ['Gary', 'is', 'young', False]
# ['someone', 'is', 'big', True]
# ['someone', 'is', 'green', True]
# ['someone', 'is', 'smart', False]
# ['someone', 'is', 'nice', True]
# ['Dave', 'is', 'furry', True]
# ['Harry', 'is', 'big', True]
# ['something', 'is', 'furry', True]
# ['something', 'is', 'kind', True]
# ['something', 'is', 'furry', True]
# ['Anne', 'is', 'green', True]
# ['Anne', 'is', 'quiet', True]
# ['Anne', 'is', 'rough', True]
# ['Anne', 'is', 'round', True]
# ['Anne', 'is', 'smart', True]
# ['Anne', 'is', 'white', True]
# ['Charlie', 'is', 'nice', True]
# ['Charlie', 'is', 'quiet', True]
# ['Charlie', 'is', 'round', True]
# ['Gary', 'is', 'nice', True]
# ['Gary', 'is', 'rough', True]
# ['Gary', 'is', 'round', True]
# ['someone', 'is', 'quiet', True]
# ['someone', 'is', 'white', True]
# ['bear', 'is', 'red', False]
# ['mouse', 'is', 'kind', False]
# ['rabbit', 'likes', 'mouse', True]
# ['bear', 'likes', 'rabbit', False]
# ['mouse', 'likes', 'rabbit', False]
# ['bear', 'likes', 'mouse', True]
# ['mouse', 'visits', 'bear', True]
# ['mouse', 'likes', 'bear', True]
# ['someone', 'is', 'kind', False]
# ['someone', 'likes', 'bear', False]
# ['bear', 'visits', 'mouse', True]
# ['dog', 'eats', 'rabbit', True]
# ['dog', 'visits', 'lion', True]
# ['lion', 'chases', 'dog', True]
# ['lion', 'chases', 'rabbit', True]
# ['lion', 'eats', 'dog', True]
# ['lion', 'is', 'big', True]
# ['lion', 'is', 'round', True]
# ['lion', 'visits', 'dog', True]
# ['rabbit', 'eats', 'dog', True]
# ['rabbit', 'is', 'blue', True]
# ['rabbit', 'is', 'red', True]
# ['rabbit', 'visits', 'squirrel', True]
# ['squirrel', 'chases', 'lion', True]
# ['squirrel', 'eats', 'lion', True]
# ['squirrel', 'eats', 'rabbit', True]
# ['squirrel', 'visits', 'dog', True]
# ['someone', 'is', 'big', True]
# ['someone', 'eats', 'squirrel', True]
# ['Anne', 'is', 'green', True]
# ['Anne', 'is', 'red', True]
# ['Anne', 'is', 'young', True]
# ['Erin', 'is', 'green', False]
# ['Erin', 'is', 'nice', True]
# ['Erin', 'is', 'red', True]
# ['Erin', 'is', 'smart', True]
# ['Erin', 'is', 'young', True]
# ['Fiona', 'is', 'green', True]
# ['Fiona', 'is', 'young', True]
# ['something', 'is', 'nice', True]
# ['something', 'is', 'blue', True]
# ['bald eagle', 'chases', 'tiger', False]
# ['bald eagle', 'is', 'nice', True]
# ['dog', 'chases', 'squirrel', True]
# ['dog', 'is', 'young', False]
# ['dog', 'sees', 'bald eagle', True]
# ['dog', 'sees', 'squirrel', True]
# ['squirrel', 'chases', 'bald eagle', True]
# ['squirrel', 'is', 'kind', False]
# ['squirrel', 'is', 'young', False]
# ['squirrel', 'sees', 'bald eagle', True]
# ['squirrel', 'sees', 'tiger', True]
# ['tiger', 'sees', 'bald eagle', True]
# ['bald eagle', 'visits', 'dog', True]
# ['squirrel', 'is', 'young', True]
# ['dog', 'is', 'round', False]
# ['bald eagle', 'visits', 'tiger', True]
# ['tiger', 'needs', 'bald eagle', True]
# ['tiger', 'needs', 'bald eagle', True]
# ['bald eagle', 'sees', 'tiger', True]
# ['something', 'needs', 'bald eagle', False]
# ['tiger', 'needs', 'bald eagle', True]
# ['bald eagle', 'sees', 'tiger', False]
# ['something', 'is', 'rough', True]
# ['bald eagle', 'visits', 'tiger', True]
# ['tiger', 'is', 'young', True]
# ['cat', 'visits', 'rabbit', False]
# ['rabbit', 'eats', 'cat', True]
# ['rabbit', 'is', 'round', True]
# ['something', 'eats', 'rabbit', False]
# ['something', 'eats', 'rabbit', False]
# ['something', 'eats', 'cat', True]
# ['rabbit', 'eats', 'cat', True]
# ['something', 'visits', 'cat', True]
# ['cat', 'eats', 'rabbit', True]
# ['Anne', 'is', 'green', True]
# ['Charlie', 'is', 'round', True]
# ['Erin', 'is', 'quiet', True]
# ['Harry', 'is', 'rough', True]
# ['something', 'is', 'cold', True]
# ['Harry', 'is', 'round', True]
# ['bear', 'visits', 'squirrel', True]
# ['dog', 'eats', 'bear', False]
# ['squirrel', 'likes', 'bear', True]
# ['someone', 'eats', 'dog', True]
# ['squirrel', 'is', 'nice', True]
# ['someone', 'is', 'nice', True]
# ['bear', 'likes', 'dog', True]
# ['someone', 'visits', 'dog', True]
# ['someone', 'is', 'kind', True]
# ['squirrel', 'likes', 'dog', True]
# ['someone', 'eats', 'dog', True]
# ['Anne', 'is', 'quiet', True]
# ['Fiona', 'is', 'big', True]
# ['something', 'is', 'green', True]
# ['Fiona', 'is', 'furry', True]
# ['something', 'is', 'green', True]
# ['Fiona', 'is', 'kind', True]
# ['something', 'is', 'kind', True]
# ['something', 'is', 'kind', True]
# ['bear', 'is', 'blue', True]
# ['bear', 'needs', 'dog', True]
# ['cow', 'needs', 'dog', True]
# ['cow', 'needs', 'squirrel', True]
# ['dog', 'is', 'cold', True]
# ['dog', 'needs', 'bear', True]
# ['dog', 'visits', 'squirrel', True]
# ['squirrel', 'is', 'kind', True]
# ['squirrel', 'needs', 'cow', True]
# ['squirrel', 'visits', 'bear', True]
# ['dog', 'needs', 'squirrel', True]
# ['someone', 'is', 'blue', True]
# ['someone', 'visits', 'cow', True]
# ['bear', 'visits', 'squirrel', True]
# ['dog', 'likes', 'squirrel', True]
# ['squirrel', 'needs', 'cow', True]
# ['cow', 'is', 'big', True]
# ['squirrel', 'needs', 'cow', True]
# ['Bob', 'is', 'big', True]
# ['Bob', 'is', 'green', True]
# ['Bob', 'is', 'red', True]
# ['Bob', 'is', 'rough', True]
# ['Bob', 'is', 'young', True]
# ['Charlie', 'is', 'big', True]
# ['Charlie', 'is', 'furry', True]
# ['Charlie', 'is', 'green', True]
# ['Charlie', 'is', 'red', True]
# ['Charlie', 'is', 'rough', True]
# ['Charlie', 'is', 'smart', True]
# ['Charlie', 'is', 'young', True]
# ['something', 'is', 'smart', True]
# ['Bob', 'is', 'red', True]
# ['something', 'is', 'furry', True]
# ['Gary', 'is', 'round', True]
# ['Gary', 'is', 'young', True]
# ['something', 'is', 'cold', True]
# ['something', 'is', 'nice', True]
# ['something', 'is', 'young', True]
# ['something', 'is', 'round', True]
# ['something', 'is', 'smart', True]
# ['Bob', 'is', 'big', True]
# ['Bob', 'is', 'red', True]
# ['Bob', 'is', 'rough', True]
# ['Bob', 'is', 'white', True]
# ['Dave', 'is', 'big', True]
# ['Dave', 'is', 'rough', True]
# ['Erin', 'is', 'cold', True]
# ['Erin', 'is', 'rough', True]
# ['Erin', 'is', 'round', True]
# ['Erin', 'is', 'smart', True]
# ['someone', 'is', 'round', True]
# ['someone', 'is', 'smart', True]
# ['someone', 'is', 'cold', True]
# ['Charlie', 'is', 'blue', True]
# ['Charlie', 'is', 'furry', True]
# ['Charlie', 'is', 'green', True]
# ['Charlie', 'is', 'nice', True]
# ['Charlie', 'is', 'quiet', True]
# ['Charlie', 'is', 'rough', True]
# ['Charlie', 'is', 'smart', True]
# ['Harry', 'is', 'green', True]
# ['Harry', 'is', 'quiet', True]
# ['Harry', 'is', 'smart', True]
# ['something', 'is', 'furry', True]
# ['something', 'is', 'blue', True]
# ['something', 'is', 'nice', True]
# ['Harry', 'is', 'blue', True]
# ['something', 'is', 'furry', True]
# ['something', 'is', 'rough', True]
# ['bear', 'is', 'big', True]
# ['lion', 'eats', 'tiger', True]
# ['rabbit', 'sees', 'tiger', True]
# ['tiger', 'is', 'nice', True]
# ['rabbit', 'sees', 'tiger', True]
# ['rabbit', 'is', 'round', True]
# ['someone', 'likes', 'tiger', True]
# ['someone', 'is', 'cold', True]
# ['tiger', 'sees', 'rabbit', True]
# ['someone', 'likes', 'rabbit', True]
# ['Bob', 'is', 'green', True]
# ['Bob', 'is', 'kind', True]
# ['Bob', 'is', 'nice', False]
# ['Bob', 'is', 'rough', True]
# ['Bob', 'is', 'round', True]
# ['Bob', 'is', 'young', True]
# ['Gary', 'is', 'green', True]
# ['Gary', 'is', 'kind', True]
# ['Gary', 'is', 'rough', True]
# ['Gary', 'is', 'round', True]
# ['someone', 'is', 'rough', True]
# ['someone', 'is', 'quiet', True]
# ['someone', 'is', 'young', True]
# ['mouse', 'likes', 'rabbit', True]
# ['rabbit', 'sees', 'mouse', True]
# ['mouse', 'sees', 'rabbit', True]
# ['something', 'sees', 'rabbit', False]
# ['rabbit', 'is', 'young', False]
# ['something', 'is', 'red', True]
# ['something', 'sees', 'rabbit', True]
# ['mouse', 'sees', 'rabbit', True]
# ['Anne', 'is', 'smart', True]
# ['Fiona', 'is', 'smart', True]
# ['Harry', 'is', 'blue', True]
# ['something', 'is', 'white', True]
# ['something', 'is', 'kind', True]
# ['something', 'is', 'green', True]
# ['Anne', 'is', 'big', True]
# ['Anne', 'is', 'cold', True]
# ['Anne', 'is', 'furry', True]
# ['Anne', 'is', 'red', True]
# ['Anne', 'is', 'round', True]
# ['Bob', 'is', 'big', True]
# ['Bob', 'is', 'cold', False]
# ['Bob', 'is', 'furry', False]
# ['Bob', 'is', 'red', True]
# ['Fiona', 'is', 'big', False]
# ['Fiona', 'is', 'furry', True]
# ['Fiona', 'is', 'round', True]
# ['Fiona', 'is', 'quiet', True]
# ['someone', 'is', 'red', True]
# ['someone', 'is', 'round', True]
# ['someone', 'is', 'cold', True]
# ['someone', 'is', 'green', True]
# ['someone', 'is', 'quiet', True]
# ['Erin', 'is', 'big', True]
# ['Erin', 'is', 'kind', True]
# ['Erin', 'is', 'round', True]
# ['Erin', 'is', 'young', True]
# ['Fiona', 'is', 'big', True]
# ['Gary', 'is', 'big', True]
# ['Gary', 'is', 'kind', True]
# ['Harry', 'is', 'big', True]
# ['Harry', 'is', 'quiet', True]
# ['Harry', 'is', 'young', True]
# ['something', 'is', 'quiet', True]
# ['something', 'is', 'big', True]
# ['something', 'is', 'kind', True]
# ['something', 'is', 'furry', True]
# ['something', 'is', 'round', True]
# ['something', 'is', 'furry', True]
# ['something', 'is', 'quiet', True]
# ['something', 'is', 'round', True]
# ['Anne', 'is', 'big', True]
# ['Anne', 'is', 'red', True]
# ['Anne', 'is', 'rough', True]
# ['Anne', 'is', 'round', True]
# ['Anne', 'is', 'smart', True]
# ['Dave', 'is', 'blue', True]
# ['Dave', 'is', 'nice', True]
# ['Dave', 'is', 'rough', True]
# ['Dave', 'is', 'smart', True]
# ['Gary', 'is', 'big', True]
# ['Gary', 'is', 'nice', True]
# ['Gary', 'is', 'red', True]
# ['Gary', 'is', 'rough', True]
# ['Gary', 'is', 'round', True]
# ['Gary', 'is', 'smart', True]
# ['someone', 'is', 'round', True]
# ['someone', 'is', 'red', True]
# ['someone', 'is', 'big', True]
# ['Anne', 'is', 'nice', True]
# ['someone', 'is', 'rough', True]
# ['someone', 'is', 'rough', True]
# ['someone', 'is', 'red', True]
# ['someone', 'is', 'round', True]
# ['bald eagle', 'likes', 'lion', True]
# ['bald eagle', 'visits', 'bear', True]
# ['bald eagle', 'visits', 'cow', True]
# ['bear', 'chases', 'cow', True]
# ['bear', 'is', 'round', True]
# ['bear', 'is', 'young', True]
# ['bear', 'likes', 'bald eagle', True]
# ['bear', 'likes', 'lion', True]
# ['cow', 'chases', 'bear', True]
# ['cow', 'is', 'round', True]
# ['cow', 'is', 'young', True]
# ['cow', 'visits', 'bald eagle', True]
# ['lion', 'chases', 'bald eagle', True]
# ['lion', 'chases', 'bear', True]
# ['lion', 'visits', 'bald eagle', True]
# ['lion', 'visits', 'bear', True]
# ['something', 'likes', 'lion', True]
# ['something', 'is', 'kind', True]
# ['cow', 'visits', 'bald eagle', True]
# ['something', 'visits', 'lion', True]
# ['something', 'visits', 'cow', True]
# ['something', 'likes', 'bald eagle', True]
# ['bald eagle', 'is', 'round', True]
# ['something', 'chases', 'bald eagle', True]
# ['Charlie', 'is', 'blue', True]
# ['Charlie', 'is', 'green', True]
# ['Charlie', 'is', 'round', True]
# ['Erin', 'is', 'blue', True]
# ['Erin', 'is', 'quiet', False]
# ['Erin', 'is', 'smart', True]
# ['Erin', 'is', 'young', False]
# ['Harry', 'is', 'big', False]
# ['Harry', 'is', 'round', True]
# ['Harry', 'is', 'young', True]
# ['someone', 'is', 'green', True]
# ['someone', 'is', 'smart', False]
# ['bear', 'is', 'green', True]
# ['squirrel', 'needs', 'tiger', True]
# ['tiger', 'likes', 'squirrel', True]
# ['squirrel', 'is', 'cold', True]
# ['squirrel', 'is', 'blue', True]
# ['someone', 'needs', 'squirrel', True]
# ['Bob', 'is', 'big', True]
# ['Bob', 'is', 'furry', True]
# ['Bob', 'is', 'red', True]
# ['Bob', 'is', 'round', True]
# ['Dave', 'is', 'blue', True]
# ['Dave', 'is', 'furry', True]
# ['Dave', 'is', 'red', True]
# ['Harry', 'is', 'big', True]
# ['Harry', 'is', 'cold', True]
# ['Harry', 'is', 'red', True]
# ['something', 'is', 'nice', True]
# ['something', 'is', 'round', True]
# ['dog', 'is', 'kind', True]
# ['tiger', 'is', 'rough', True]
# ['someone', 'sees', 'dog', True]
# ['someone', 'chases', 'tiger', True]
# ['someone', 'sees', 'dog', False]
# ['someone', 'likes', 'tiger', True]
# ['tiger', 'is', 'rough', True]
# ['tiger', 'sees', 'dog', True]
# ['Anne', 'is', 'furry', True]
# ['Bob', 'is', 'young', True]
# ['something', 'is', 'furry', True]
# ['Anne', 'is', 'rough', True]
# ['Bob', 'is', 'quiet', True]
# ['something', 'is', 'rough', True]
# ['something', 'is', 'cold', True]
# ['Anne', 'is', 'rough', True]
# ['cow', 'is', 'blue', True]
# ['cow', 'is', 'cold', True]
# ['cow', 'is', 'kind', True]
# ['cow', 'needs', 'tiger', True]
# ['cow', 'sees', 'tiger', True]
# ['cow', 'visits', 'tiger', True]
# ['tiger', 'is', 'nice', True]
# ['tiger', 'needs', 'cow', True]
# ['tiger', 'sees', 'cow', True]
# ['tiger', 'visits', 'cow', True]
# ['tiger', 'is', 'young', True]
# ['someone', 'is', 'young', True]
# ['Anne', 'is', 'cold', True]
# ['Anne', 'is', 'furry', True]
# ['Anne', 'is', 'kind', True]
# ['Anne', 'is', 'round', True]
# ['Anne', 'is', 'white', True]
# ['Erin', 'is', 'cold', True]
# ['Erin', 'is', 'kind', True]
# ['Erin', 'is', 'round', True]
# ['Erin', 'is', 'white', True]
# ['Erin', 'is', 'young', True]
# ['Fiona', 'is', 'cold', True]
# ['Fiona', 'is', 'furry', True]
# ['Fiona', 'is', 'kind', True]
# ['Fiona', 'is', 'nice', True]
# ['Fiona', 'is', 'round', True]
# ['Fiona', 'is', 'white', True]
# ['Erin', 'is', 'cold', True]
# ['something', 'is', 'furry', True]
# ['Erin', 'is', 'nice', True]
# ['mouse', 'is', 'rough', True]
# ['mouse', 'likes', 'tiger', False]
# ['tiger', 'is', 'big', True]
# ['mouse', 'likes', 'tiger', True]
# ['tiger', 'visits', 'mouse', False]
# ['someone', 'is', 'round', False]
# ['someone', 'chases', 'tiger', True]
# ['someone', 'is', 'round', True]
# ['tiger', 'is', 'kind', True]
# ['cat', 'likes', 'tiger', True]
# ['rabbit', 'chases', 'cat', True]
# ['rabbit', 'chases', 'tiger', True]
# ['rabbit', 'is', 'nice', True]
# ['rabbit', 'is', 'young', True]
# ['rabbit', 'likes', 'cat', True]
# ['rabbit', 'visits', 'cat', True]
# ['rabbit', 'visits', 'tiger', False]
# ['tiger', 'is', 'young', True]
# ['tiger', 'likes', 'cat', True]
# ['rabbit', 'is', 'red', False]
# ['tiger', 'is', 'young', False]
# ['someone', 'chases', 'rabbit', True]
# ['Dave', 'is', 'big', True]
# ['Dave', 'is', 'furry', True]
# ['Dave', 'is', 'red', True]
# ['Dave', 'is', 'rough', True]
# ['Dave', 'is', 'smart', True]
# ['Erin', 'is', 'big', True]
# ['Erin', 'is', 'blue', True]
# ['Erin', 'is', 'furry', True]
# ['Erin', 'is', 'red', True]
# ['Erin', 'is', 'rough', True]
# ['Erin', 'is', 'smart', True]
# ['Erin', 'is', 'young', True]
# ['someone', 'is', 'furry', True]
# ['someone', 'is', 'blue', True]
# ['someone', 'is', 'young', True]
# ['someone', 'is', 'big', True]
# ['someone', 'is', 'furry', True]
# ['Dave', 'is', 'blue', True]
# ['Anne', 'is', 'red', True]
# ['Dave', 'is', 'rough', True]
# ['Erin', 'is', 'cold', True]
# ['Fiona', 'is', 'green', True]
# ['something', 'is', 'cold', True]
# ['something', 'is', 'cold', True]
# ['something', 'is', 'cold', True]
# ['Erin', 'is', 'nice', True]
# ['something', 'is', 'red', True]
# ['something', 'is', 'nice', True]
# ['something', 'is', 'kind', True]
# ['something', 'is', 'red', True]
# ['dog', 'sees', 'lion', True]
# ['lion', 'is', 'young', True]
# ['lion', 'is', 'blue', True]
# ['something', 'sees', 'dog', True]
# ['dog', 'sees', 'lion', True]
# ['something', 'visits', 'dog', True]
# ['something', 'sees', 'dog', True]
# ['something', 'eats', 'dog', True]
# ['cow', 'is', 'nice', True]
# ['cow', 'visits', 'dog', True]
# ['cow', 'visits', 'lion', True]
# ['cow', 'visits', 'rabbit', True]
# ['dog', 'eats', 'lion', True]
# ['dog', 'sees', 'cow', True]
# ['dog', 'sees', 'rabbit', True]
# ['lion', 'is', 'big', True]
# ['lion', 'sees', 'dog', True]
# ['rabbit', 'eats', 'cow', True]
# ['cow', 'is', 'green', True]
# ['someone', 'sees', 'cow', True]
# ['cow', 'sees', 'lion', True]
# ['dog', 'chases', 'squirrel', True]
# ['dog', 'chases', 'tiger', False]
# ['dog', 'eats', 'squirrel', True]
# ['dog', 'eats', 'tiger', True]
# ['dog', 'is', 'rough', True]
# ['dog', 'is', 'round', True]
# ['dog', 'sees', 'squirrel', True]
# ['squirrel', 'eats', 'dog', False]
# ['squirrel', 'eats', 'tiger', True]
# ['tiger', 'eats', 'squirrel', False]
# ['tiger', 'is', 'young', True]
# ['tiger', 'sees', 'squirrel', False]
# ['someone', 'is', 'rough', True]
# ['tiger', 'sees', 'squirrel', True]
# ['squirrel', 'is', 'round', True]
# ['someone', 'sees', 'tiger', True]
# ['tiger', 'sees', 'dog', True]
# ['tiger', 'chases', 'squirrel', False]
# ['tiger', 'chases', 'squirrel', False]
# ['someone', 'sees', 'tiger', True]
# ['cow', 'sees', 'mouse', True]
# ['cow', 'visits', 'rabbit', True]
# ['lion', 'is', 'green', True]
# ['lion', 'is', 'kind', True]
# ['mouse', 'sees', 'rabbit', True]
# ['rabbit', 'likes', 'cow', True]
# ['rabbit', 'sees', 'mouse', True]
# ['something', 'likes', 'rabbit', True]
# ['cow', 'likes', 'rabbit', True]
# ['something', 'visits', 'mouse', True]
# ['mouse', 'likes', 'rabbit', True]
# ['lion', 'visits', 'cow', True]
# ['cow', 'visits', 'lion', True]
# ['rabbit', 'is', 'kind', True]
# ['lion', 'is', 'rough', True]
# ['Anne', 'is', 'big', True]
# ['Anne', 'is', 'nice', True]
# ['Anne', 'is', 'quiet', True]
# ['Anne', 'is', 'red', True]
# ['Anne', 'is', 'rough', True]
# ['Anne', 'is', 'smart', True]
# ['Harry', 'is', 'big', True]
# ['Harry', 'is', 'blue', True]
# ['Harry', 'is', 'nice', True]
# ['Harry', 'is', 'smart', True]
# ['something', 'is', 'red', True]
# ['something', 'is', 'rough', True]
# ['Anne', 'is', 'big', True]
# ['Charlie', 'is', 'kind', True]
# ['Fiona', 'is', 'quiet', True]
# ['Fiona', 'is', 'round', True]
# ['Fiona', 'is', 'white', True]
# ['Gary', 'is', 'big', True]
# ['Gary', 'is', 'blue', True]
# ['Gary', 'is', 'green', True]
# ['Gary', 'is', 'kind', True]
# ['Gary', 'is', 'quiet', True]
# ['Gary', 'is', 'round', True]
# ['Gary', 'is', 'white', True]
# ['someone', 'is', 'quiet', True]
# ['someone', 'is', 'big', True]
# ['someone', 'is', 'round', True]
# ['Charlie', 'is', 'big', True]
# ['Charlie', 'is', 'green', True]
# ['Charlie', 'is', 'quiet', True]
# ['Charlie', 'is', 'red', True]
# ['Charlie', 'is', 'rough', True]
# ['Charlie', 'is', 'white', True]
# ['Charlie', 'is', 'young', True]
# ['Fiona', 'is', 'big', True]
# ['Fiona', 'is', 'red', True]
# ['Fiona', 'is', 'rough', True]
# ['Fiona', 'is', 'white', True]
# ['Fiona', 'is', 'young', True]
# ['Fiona', 'is', 'green', True]
# ['someone', 'is', 'green', True]
# ['someone', 'is', 'green', True]
# ['someone', 'is', 'rough', True]
# ['someone', 'is', 'rough', True]
# ['someone', 'is', 'rough', True]
# ['someone', 'is', 'white', True]
# ['Fiona', 'is', 'quiet', True]
# ['Anne', 'is', 'young', True]
# ['Bob', 'is', 'round', True]
# ['Fiona', 'is', 'green', True]
# ['Gary', 'is', 'round', True]
# ['something', 'is', 'round', True]
# ['something', 'is', 'furry', True]
# ['Anne', 'is', 'green', True]
# ['Gary', 'is', 'furry', True]
# ['Gary', 'is', 'green', True]
# ['something', 'is', 'white', True]
# ...
# ['bald eagle', 'is', 'red', True]
# ['bald eagle', 'is', 'rough', True]
# ['bald eagle', 'likes', 'rabbit', True]
# ['bald eagle', 'needs', 'rabbit', False]
# ['lion', 'eats', 'mouse', True]
# ['lion', 'likes', 'bald eagle', False]
# ['lion', 'likes', 'mouse', False]
# ['lion', 'needs', 'bald eagle', True]
# ['mouse', 'eats', 'rabbit', True]
# ['mouse', 'is', 'round', True]
# ['mouse', 'likes', 'lion', False]
# ['mouse', 'needs', 'lion', True]
# ['mouse', 'needs', 'rabbit', True]
# ['rabbit', 'is', 'rough', True]
# ['rabbit', 'likes', 'mouse', True]
# ['rabbit', 'needs', 'bald eagle', True]
# ['bald eagle', 'eats', 'mouse', False]
# ['rabbit', 'likes', 'lion', True]
# ['lion', 'needs', 'rabbit', True]
# ['someone', 'likes', 'bald eagle', False]
# ['lion', 'eats', 'rabbit', False]
# ['rabbit', 'is', 'rough', True]
# ['Dave', 'is', 'blue', True]
# ['Dave', 'is', 'furry', True]
# ['Dave', 'is', 'kind', True]
# ['Dave', 'is', 'red', True]
# ['Dave', 'is', 'young', True]
# ['Fiona', 'is', 'blue', True]
# ['Fiona', 'is', 'cold', False]
# ['Fiona', 'is', 'furry', True]
# ['Fiona', 'is', 'kind', True]
# ['Fiona', 'is', 'red', True]
# ['Fiona', 'is', 'rough', True]
# ['Fiona', 'is', 'young', True]
# ['Dave', 'is', 'young', True]
# ['something', 'is', 'red', True]
# ['Dave', 'is', 'cold', True]
# ['something', 'is', 'rough', True]
# ['something', 'is', 'young', True]
# ['something', 'is', 'furry', True]
# ['cat', 'eats', 'squirrel', True]
# ['cat', 'is', 'big', True]
# ['cat', 'is', 'rough', True]
# ['cat', 'likes', 'squirrel', True]
# ['cat', 'visits', 'squirrel', True]
# ['dog', 'eats', 'cat', True]
# ['dog', 'eats', 'squirrel', True]
# ['dog', 'is', 'big', True]
# ['squirrel', 'eats', 'dog', True]
# ['squirrel', 'is', 'big', True]
# ['squirrel', 'is', 'kind', True]
# ['squirrel', 'is', 'young', True]
# ['squirrel', 'likes', 'cat', True]
# ['squirrel', 'likes', 'dog', True]
# ['squirrel', 'visits', 'cat', True]
# ['squirrel', 'visits', 'dog', True]
# ['dog', 'is', 'kind', True]
# ['someone', 'likes', 'dog', True]
# ['cat', 'eats', 'dog', True]
# ['dog', 'is', 'red', True]
# ['rabbit', 'eats', 'dog', False]
# ['rabbit', 'eats', 'cat', True]
# ['something', 'chases', 'rabbit', True]
# ['rabbit', 'chases', 'dog', False]
# ['cow', 'eats', 'rabbit', True]
# ['cow', 'is', 'kind', False]
# ['cow', 'is', 'nice', True]
# ['cow', 'is', 'round', True]
# ['cow', 'likes', 'squirrel', True]
# ['cow', 'sees', 'squirrel', True]
# ['rabbit', 'eats', 'squirrel', True]
# ['rabbit', 'is', 'red', True]
# ['rabbit', 'likes', 'squirrel', True]
# ['rabbit', 'sees', 'cow', True]
# ['rabbit', 'sees', 'squirrel', False]
# ['squirrel', 'eats', 'cow', False]
# ['squirrel', 'is', 'kind', True]
# ['squirrel', 'is', 'red', True]
# ['squirrel', 'likes', 'cow', True]
# ['rabbit', 'is', 'blue', True]
# ['someone', 'likes', 'rabbit', False]
# ['squirrel', 'sees', 'rabbit', True]
# ['squirrel', 'likes', 'rabbit', True]
# ['someone', 'is', 'blue', False]
# ['cow', 'is', 'blue', True]
# ['cow', 'is', 'blue', True]
# ['someone', 'is', 'round', True]
# ['bald eagle', 'chases', 'lion', True]
# ['bald eagle', 'likes', 'lion', True]
# ['lion', 'chases', 'bald eagle', True]
# ['lion', 'is', 'cold', True]
# ['lion', 'likes', 'bald eagle', True]
# ['lion', 'likes', 'squirrel', True]
# ['mouse', 'likes', 'bald eagle', True]
# ['mouse', 'likes', 'lion', True]
# ['squirrel', 'likes', 'lion', True]
# ['squirrel', 'visits', 'lion', True]
# ['mouse', 'chases', 'squirrel', True]
# ['bald eagle', 'visits', 'mouse', True]
# ['lion', 'chases', 'rabbit', True]
# ['lion', 'is', 'blue', True]
# ['lion', 'is', 'green', True]
# ['lion', 'likes', 'rabbit', True]
# ['lion', 'sees', 'rabbit', True]
# ['rabbit', 'chases', 'lion', True]
# ['rabbit', 'is', 'big', True]
# ['rabbit', 'is', 'blue', True]
# ['rabbit', 'is', 'cold', True]
# ['rabbit', 'is', 'nice', True]
# ['rabbit', 'likes', 'lion', True]
# ['rabbit', 'sees', 'lion', True]
# ['rabbit', 'likes', 'lion', True]
# ['rabbit', 'chases', 'lion', True]
# ['lion', 'sees', 'rabbit', True]
# ['something', 'likes', 'lion', True]
# ['something', 'likes', 'rabbit', True]
# ['something', 'sees', 'rabbit', True]
# ['something', 'sees', 'rabbit', True]
# ['something', 'likes', 'lion', True]
# ['bear', 'is', 'big', True]
# ['bear', 'is', 'kind', True]
# ['bear', 'needs', 'cat', True]
# ['bear', 'needs', 'dog', True]
# ['bear', 'visits', 'cat', True]
# ['bear', 'visits', 'dog', True]
# ['cat', 'eats', 'bear', True]
# ['cat', 'is', 'big', True]
# ['cat', 'is', 'cold', True]
# ['cat', 'is', 'nice', True]
# ['cat', 'visits', 'dog', True]
# ['dog', 'eats', 'cat', True]
# ['dog', 'is', 'kind', True]
# ['dog', 'needs', 'bear', True]
# ['dog', 'needs', 'cat', True]
# ['someone', 'eats', 'dog', True]
# ['bear', 'is', 'cold', True]
# ['someone', 'visits', 'bear', True]
# ['Dave', 'is', 'big', True]
# ['Dave', 'is', 'furry', True]
# ['Dave', 'is', 'round', True]
# ['Dave', 'is', 'smart', True]
# ['Dave', 'is', 'white', True]
# ['Gary', 'is', 'big', True]
# ['Gary', 'is', 'cold', True]
# ['Gary', 'is', 'furry', True]
# ['Gary', 'is', 'nice', True]
# ['Gary', 'is', 'round', True]
# ['Harry', 'is', 'furry', True]
# ['Harry', 'is', 'round', True]
# ['something', 'is', 'cold', True]
# ['something', 'is', 'nice', True]
# ['Anne', 'is', 'furry', True]
# ['Charlie', 'is', 'furry', True]
# ['Charlie', 'is', 'kind', True]
# ['Charlie', 'is', 'round', True]
# ['Fiona', 'is', 'furry', True]
# ['Fiona', 'is', 'kind', True]
# ['Fiona', 'is', 'quiet', True]
# ['Fiona', 'is', 'round', True]
# ['Fiona', 'is', 'white', True]
# ['Harry', 'is', 'furry', True]
# ['Harry', 'is', 'kind', True]
# ['Harry', 'is', 'smart', True]
# ['Fiona', 'is', 'round', True]
# ['someone', 'is', 'round', True]
# ['someone', 'is', 'furry', True]
# ['someone', 'is', 'smart', True]
# ['Fiona', 'is', 'quiet', True]
# ['someone', 'is', 'green', True]
# ['Anne', 'is', 'cold', True]
# ['Dave', 'is', 'rough', True]
# ['Erin', 'is', 'white', True]
# ['Harry', 'is', 'rough', True]
# ['Harry', 'is', 'young', True]
# ['someone', 'is', 'white', True]
# ['someone', 'is', 'cold', True]
# ['someone', 'is', 'furry', True]
# ['someone', 'is', 'furry', True]
# ['someone', 'is', 'furry', True]
# ['someone', 'is', 'young', True]
# ['someone', 'is', 'green', True]
# ['Bob', 'is', 'blue', True]
# ['Bob', 'is', 'round', True]
# ['Harry', 'is', 'cold', True]
# ['something', 'is', 'young', True]
# ['something', 'is', 'blue', True]
# ['bear', 'eats', 'cat', True]
# ['bear', 'needs', 'squirrel', True]
# ['cat', 'chases', 'lion', True]
# ['cat', 'chases', 'squirrel', True]
# ['cat', 'eats', 'lion', True]
# ['lion', 'chases', 'bear', True]
# ['lion', 'chases', 'cat', True]
# ['lion', 'chases', 'squirrel', True]
# ['lion', 'eats', 'bear', True]
# ['lion', 'needs', 'squirrel', False]
# ['squirrel', 'is', 'green', True]
# ['squirrel', 'is', 'young', True]
# ['bear', 'chases', 'cat', True]
# ['lion', 'needs', 'bear', True]
# ['Bob', 'is', 'green', True]
# ['Fiona', 'is', 'nice', True]
# ['Fiona', 'is', 'rough', True]
# ['something', 'is', 'rough', True]
# ['something', 'is', 'white', True]
# ['something', 'is', 'furry', False]
# ['Anne', 'is', 'green', True]
# ['Bob', 'is', 'red', True]
# ['Charlie', 'is', 'big', True]
# ['something', 'is', 'young', True]
# ['something', 'is', 'rough', True]
# ['Charlie', 'is', 'blue', True]
# ['something', 'is', 'young', True]
# ['something', 'is', 'rough', True]
# ['something', 'is', 'green', True]
# ['Anne', 'is', 'kind', True]
# ['Bob', 'is', 'green', True]
# ['Harry', 'is', 'kind', True]
# ['someone', 'is', 'kind', True]
# ['someone', 'is', 'smart', True]
# ['Harry', 'is', 'white', True]
# ['cow', 'chases', 'rabbit', True]
# ['rabbit', 'sees', 'squirrel', True]
# ['squirrel', 'is', 'blue', True]
# ['something', 'eats', 'rabbit', True]
# ['something', 'sees', 'rabbit', True]
# ['rabbit', 'chases', 'squirrel', True]
# ['cow', 'chases', 'squirrel', False]
# ['squirrel', 'chases', 'rabbit', False]
# ['cow', 'is', 'red', True]
# ['Bob', 'is', 'kind', False]
# ['Bob', 'is', 'round', False]
# ['Bob', 'is', 'smart', True]
# ['Fiona', 'is', 'big', True]
# ['Fiona', 'is', 'green', True]
# ['Fiona', 'is', 'kind', False]
# ['Fiona', 'is', 'rough', False]
# ['Fiona', 'is', 'smart', True]
# ['Gary', 'is', 'quiet', True]
# ['Gary', 'is', 'round', True]
# ['Harry', 'is', 'green', False]
# ['Harry', 'is', 'kind', True]
# ['Harry', 'is', 'quiet', False]
# ['Harry', 'is', 'rough', True]
# ['Harry', 'is', 'round', True]
# ['Harry', 'is', 'smart', True]
# ['something', 'is', 'big', True]
# ['something', 'is', 'big', True]
# ['something', 'is', 'rough', False]
# ['something', 'is', 'big', True]
# ['something', 'is', 'kind', True]
# ['Bob', 'is', 'quiet', True]
# ['something', 'is', 'smart', True]
# ['something', 'is', 'kind', False]
# ['bear', 'needs', 'mouse', True]
# ['mouse', 'likes', 'bear', True]
# ['tiger', 'sees', 'bear', True]
# ['someone', 'likes', 'mouse', True]
# ['someone', 'sees', 'tiger', True]
# ['cat', 'is', 'kind', True]
# ['cat', 'needs', 'mouse', True]
# ['cat', 'sees', 'mouse', True]
# ['cow', 'chases', 'cat', True]
# ['cow', 'sees', 'cat', True]
# ['cow', 'sees', 'mouse', True]
# ['dog', 'is', 'blue', True]
# ['dog', 'needs', 'cat', True]
# ['dog', 'needs', 'cow', True]
# ['dog', 'sees', 'cow', False]
# ['mouse', 'needs', 'cow', True]
# ['mouse', 'sees', 'dog', True]
# ['cow', 'sees', 'dog', True]
# ['something', 'sees', 'mouse', True]
# ['cat', 'chases', 'dog', True]
# ['mouse', 'is', 'cold', False]
# ['something', 'is', 'blue', True]
# ['something', 'is', 'cold', True]
# ['something', 'needs', 'dog', True]
# ['dog', 'chases', 'mouse', True]
# ['dog', 'is', 'nice', True]
# ['dog', 'is', 'rough', True]
# ['dog', 'is', 'round', True]
# ['something', 'is', 'nice', True]
# ['dog', 'is', 'rough', True]
# ['something', 'is', 'red', True]
# ['something', 'is', 'rough', True]
# ['something', 'is', 'big', True]
# ['something', 'is', 'round', True]
# ['Charlie', 'is', 'rough', True]
# ['Dave', 'is', 'kind', True]
# ['Gary', 'is', 'cold', True]
# ['something', 'is', 'cold', True]
# ['something', 'is', 'cold', True]
# ['Gary', 'is', 'red', True]
# ['something', 'is', 'big', True]
# ['something', 'is', 'blue', True]
# ['something', 'is', 'cold', True]
# ['something', 'is', 'red', True]
# ['something', 'is', 'rough', True]
# ['cow', 'eats', 'lion', True]
# ['lion', 'eats', 'mouse', True]
# ['lion', 'is', 'kind', False]
# ['lion', 'is', 'young', True]
# ['lion', 'visits', 'cow', True]
# ['lion', 'visits', 'mouse', True]
# ['mouse', 'eats', 'cow', True]
# ['mouse', 'is', 'green', True]
# ['mouse', 'is', 'young', True]
# ['mouse', 'likes', 'cow', True]
# ['mouse', 'likes', 'lion', True]
# ['mouse', 'visits', 'lion', True]
# ['something', 'is', 'big', True]
# ['something', 'eats', 'mouse', False]
# ['something', 'visits', 'mouse', True]
# ['Charlie', 'is', 'blue', True]
# ['Charlie', 'is', 'green', True]
# ['Charlie', 'is', 'nice', True]
# ['Charlie', 'is', 'quiet', True]
# ['Charlie', 'is', 'young', True]
# ['Dave', 'is', 'quiet', True]
# ['Dave', 'is', 'smart', True]
# ['Erin', 'is', 'nice', True]
# ['Erin', 'is', 'smart', True]
# ['Harry', 'is', 'blue', True]
# ['Harry', 'is', 'green', True]
# ['Harry', 'is', 'nice', True]
# ['Harry', 'is', 'quiet', True]
# ['Harry', 'is', 'round', True]
# ['Harry', 'is', 'smart', True]
# ['something', 'is', 'quiet', True]
# ['something', 'is', 'blue', True]
# ['something', 'is', 'smart', True]
# ['rabbit', 'chases', 'tiger', True]
# ['rabbit', 'needs', 'tiger', True]
# ['tiger', 'is', 'big', True]
# ['tiger', 'is', 'blue', False]
# ['tiger', 'is', 'cold', False]
# ['tiger', 'is', 'rough', False]
# ['tiger', 'visits', 'rabbit', True]
# ['someone', 'is', 'rough', True]
# ['someone', 'needs', 'rabbit', True]
# ['someone', 'chases', 'tiger', True]
# ['someone', 'visits', 'rabbit', True]
# ['someone', 'is', 'rough', True]
# ['someone', 'is', 'big', True]
# ['rabbit', 'visits', 'tiger', True]
# ['tiger', 'is', 'red', False]
# ['Bob', 'is', 'green', True]
# ['Charlie', 'is', 'cold', True]
# ['Charlie', 'is', 'smart', True]
# ['Gary', 'is', 'big', True]
# ['Gary', 'is', 'green', True]
# ['Gary', 'is', 'white', True]
# ['Gary', 'is', 'young', True]
# ['Gary', 'is', 'cold', True]
# ['someone', 'is', 'blue', True]
# ['Gary', 'is', 'cold', True]
# ['Gary', 'is', 'green', True]
# ['Gary', 'is', 'quiet', True]
# ['something', 'is', 'rough', True]
# ['something', 'is', 'young', True]
# ['something', 'is', 'furry', True]
# ['something', 'is', 'furry', False]
# ['something', 'is', 'smart', True]
# ['something', 'is', 'quiet', True]
# ['something', 'is', 'young', True]
# ['something', 'is', 'furry', True]
# ['cat', 'is', 'young', True]
# ['dog', 'visits', 'cat', True]
# ['squirrel', 'is', 'big', True]
# ['tiger', 'visits', 'cat', True]
# ['tiger', 'is', 'young', True]
# ['something', 'is', 'nice', True]
# ['dog', 'likes', 'tiger', True]
# ['something', 'visits', 'tiger', True]
# ['cat', 'is', 'big', True]
# ['dog', 'is', 'young', True]
# ['dog', 'is', 'green', True]
# ['squirrel', 'likes', 'dog', True]
# ['bald eagle', 'chases', 'cat', True]
# ['bald eagle', 'is', 'blue', False]
# ['bald eagle', 'is', 'cold', True]
# ['cat', 'is', 'cold', True]
# ['cow', 'is', 'round', True]
# ['dog', 'is', 'cold', False]
# ['dog', 'is', 'green', True]
# ['cat', 'is', 'blue', True]
# ['something', 'likes', 'bald eagle', True]
# ['cow', 'chases', 'dog', True]
# ['bald eagle', 'chases', 'dog', False]
# ['cow', 'chases', 'cat', True]
# ['something', 'sees', 'cow', True]
# ['something', 'likes', 'bald eagle', False]
# ['something', 'likes', 'dog', True]
# ['Anne', 'is', 'blue', True]
# ['Anne', 'is', 'round', True]
# ['Anne', 'is', 'white', True]
# ['Bob', 'is', 'blue', True]
# ['Bob', 'is', 'cold', True]
# ['Bob', 'is', 'furry', True]
# ['Bob', 'is', 'kind', True]
# ['Bob', 'is', 'round', True]
# ['Bob', 'is', 'white', True]
# ['Bob', 'is', 'young', True]
# ['Charlie', 'is', 'blue', True]
# ['Charlie', 'is', 'furry', True]
# ['Charlie', 'is', 'kind', True]
# ['Charlie', 'is', 'round', True]
# ['Charlie', 'is', 'white', True]
# ['Charlie', 'is', 'young', True]
# ['something', 'is', 'cold', True]
# ['something', 'is', 'young', True]
# ['cow', 'needs', 'rabbit', True]
# ['rabbit', 'is', 'rough', True]
# ['squirrel', 'eats', 'cow', True]
# ['something', 'needs', 'rabbit', True]
# ['something', 'needs', 'cow', True]
# ['something', 'eats', 'cow', True]
# ['something', 'chases', 'cow', True]
# ['rabbit', 'is', 'kind', True]
# ['something', 'eats', 'cow', True]
# ['Charlie', 'is', 'big', True]
# ['Charlie', 'is', 'green', True]
# ['Charlie', 'is', 'red', True]
# ['Charlie', 'is', 'round', True]
# ['Charlie', 'is', 'young', True]
# ['Erin', 'is', 'green', True]
# ['Erin', 'is', 'red', True]
# ['Erin', 'is', 'smart', True]
# ['Erin', 'is', 'young', True]
# ['Fiona', 'is', 'round', True]
# ['Fiona', 'is', 'young', True]
# ['Harry', 'is', 'big', True]
# ['Harry', 'is', 'cold', True]
# ['Harry', 'is', 'round', True]
# ['Harry', 'is', 'young', True]
# ['someone', 'is', 'big', True]
# ['someone', 'is', 'cold', True]
# ['someone', 'is', 'smart', True]
# ['someone', 'is', 'cold', True]
# ['Charlie', 'is', 'smart', True]
# ['someone', 'is', 'cold', True]
# ['mouse', 'is', 'nice', False]
# ['someone', 'is', 'round', False]
# ['someone', 'is', 'big', False]
# ['mouse', 'is', 'rough', True]
# ['someone', 'is', 'kind', True]
# ['mouse', 'is', 'round', True]
# ['someone', 'is', 'nice', True]
# ['Anne', 'is', 'green', True]
# ['Anne', 'is', 'smart', True]
# ['Dave', 'is', 'blue', True]
# ['Dave', 'is', 'cold', True]
# ['Dave', 'is', 'smart', True]
# ['Dave', 'is', 'white', True]
# ['Fiona', 'is', 'blue', True]
# ['Fiona', 'is', 'smart', True]
# ['Fiona', 'is', 'white', True]
# ['Harry', 'is', 'cold', True]
# ['Fiona', 'is', 'quiet', True]
# ['something', 'is', 'blue', True]
# ['something', 'is', 'quiet', True]
# ['Bob', 'is', 'big', True]
# ['Gary', 'is', 'furry', True]
# ['Gary', 'is', 'round', True]
# ['someone', 'is', 'round', True]
# ['someone', 'is', 'green', True]
# ['someone', 'is', 'blue', True]
# ['someone', 'is', 'young', True]
# ['someone', 'is', 'blue', True]
# ['Gary', 'is', 'green', True]
# ['Anne', 'is', 'blue', True]
# ['Erin', 'is', 'green', True]
# ['something', 'is', 'blue', True]
# ['something', 'is', 'red', True]
# ['Anne', 'is', 'green', True]
# ['bear', 'chases', 'cat', True]
# ['bear', 'sees', 'cat', True]
# ['cat', 'eats', 'rabbit', False]
# ['cat', 'is', 'young', False]
# ['cat', 'sees', 'bear', True]
# ['cat', 'sees', 'rabbit', True]
# ['lion', 'chases', 'cat', True]
# ['lion', 'chases', 'rabbit', True]
# ['lion', 'is', 'young', True]
# ['rabbit', 'is', 'rough', False]
# ['something', 'eats', 'lion', True]
# ['lion', 'eats', 'rabbit', True]
# ['cat', 'eats', 'rabbit', True]
# ['cat', 'is', 'kind', True]
# ['bear', 'sees', 'lion', True]
# ['something', 'sees', 'bear', True]
# ['cat', 'eats', 'bear', True]
# ['something', 'sees', 'lion', True]

# %%
import pprint
id = 'RelNoneg-D2-2133'
print("data_worlds[%s] contains the following rules:"%(id))
pprint.PrettyPrinter(indent=1).pprint(data_worlds[id]['rules'])
print("")
print("... and the following questions:")
pprint.PrettyPrinter(indent=1).pprint(data_worlds[id]['questions'])
# Out:
# data_worlds[RelNoneg-D2-2133] contains the following rules:
# {'rule1': {'antecedents': [['something', 'eats', 'tiger', True]],
#            'consequent': ['something', 'sees', 'tiger', True],
#            'text': 'If something eats the tiger then it sees the tiger.'},
#  'rule2': {'antecedents': [['something', 'visits', 'bald eagle', True]],
#            'consequent': ['something', 'eats', 'tiger', True],
#            'text': 'If something visits the bald eagle then it eats the '
#                    'tiger.'},
#  'rule3': {'antecedents': [['something', 'is', 'rough', True]],
#            'consequent': ['something', 'eats', 'tiger', True],
#            'text': 'If something is rough then it eats the tiger.'},
#  'triple1': {'antecedents': [],
#              'consequent': ['bald eagle', 'eats', 'tiger', True],
#              'text': 'The bald eagle eats the tiger.'},
#  'triple10': {'antecedents': [],
#               'consequent': ['tiger', 'is', 'green', True],
#               'text': 'The tiger is green.'},
#  'triple11': {'antecedents': [],
#               'consequent': ['tiger', 'is', 'kind', True],
#               'text': 'The tiger is kind.'},
#  'triple12': {'antecedents': [],
#               'consequent': ['tiger', 'is', 'rough', True],
#               'text': 'The tiger is rough.'},
#  'triple13': {'antecedents': [],
#               'consequent': ['tiger', 'is', 'young', True],
#               'text': 'The tiger is young.'},
#  'triple14': {'antecedents': [],
#               'consequent': ['tiger', 'sees', 'bald eagle', True],
#               'text': 'The tiger sees the bald eagle.'},
#  'triple15': {'antecedents': [],
#               'consequent': ['tiger', 'visits', 'bald eagle', True],
#               'text': 'The tiger visits the bald eagle.'},
#  'triple2': {'antecedents': [],
#              'consequent': ['bald eagle', 'is', 'blue', True],
#              'text': 'The bald eagle is blue.'},
#  'triple3': {'antecedents': [],
#              'consequent': ['bald eagle', 'is', 'green', True],
#              'text': 'The bald eagle is green.'},
#  'triple4': {'antecedents': [],
#              'consequent': ['bald eagle', 'is', 'kind', True],
#              'text': 'The bald eagle is kind.'},
#  'triple5': {'antecedents': [],
#              'consequent': ['bald eagle', 'is', 'rough', True],
#              'text': 'The bald eagle is rough.'},
#  'triple6': {'antecedents': [],
#              'consequent': ['bald eagle', 'sees', 'tiger', True],
#              'text': 'The bald eagle sees the tiger.'},
#  'triple7': {'antecedents': [],
#              'consequent': ['bald eagle', 'visits', 'tiger', True],
#              'text': 'The bald eagle visits the tiger.'},
#  'triple8': {'antecedents': [],
#              'consequent': ['tiger', 'eats', 'bald eagle', True],
#              'text': 'The tiger eats the bald eagle.'},
#  'triple9': {'antecedents': [],
#              'consequent': ['tiger', 'is', 'blue', True],
#              'text': 'The tiger is blue.'}}
#
# ... and the following questions:
# {'Q1': {'answer': True,
#         'proofs': '[(triple9)]',
#         'query': ['tiger', 'is', 'blue', True],
#         'text': 'The tiger is blue?'},
#  'Q10': {'answer': 'CWA',
#          'proofs': '[@0: The bald eagle visits the bald eagle.[CWA. Example of '
#                    'deepest failure = (FAIL)]]',
#          'query': ['bald eagle', 'visits', 'bald eagle', True],
#          'text': 'The bald eagle visits the bald eagle?'},
#  'Q2': {'answer': False,
#         'proofs': '[(triple12)]',
#         'query': ['tiger', 'is', 'rough', False],
#         'text': 'The tiger is not rough?'},
#  'Q3': {'answer': True,
#         'proofs': '[(((triple12) -> rule3) OR ((triple15) -> rule2))]',
#         'query': ['tiger', 'eats', 'tiger', True],
#         'text': 'The tiger eats the tiger?'},
#  'Q4': {'answer': False,
#         'proofs': '[(((triple12) -> rule3) OR ((triple15) -> rule2))]',
#         'query': ['tiger', 'eats', 'tiger', False],
#         'text': 'The tiger does not eat the tiger?'},
#  'Q5': {'answer': True,
#         'proofs': '[(((((triple12) -> rule3)) -> rule1) OR ((((triple15) -> '
#                   'rule2)) -> rule1))]',
#         'query': ['tiger', 'sees', 'tiger', True],
#         'text': 'The tiger sees the tiger?'},
#  'Q6': {'answer': False,
#         'proofs': '[(((((triple12) -> rule3)) -> rule1) OR ((((triple15) -> '
#                   'rule2)) -> rule1))]',
#         'query': ['tiger', 'sees', 'tiger', False],
#         'text': 'The tiger does not see the tiger?'},
#  'Q7': {'answer': 'CWA',
#         'proofs': '[@0: The tiger visits the tiger.[CWA. Example of deepest '
#                   'failure = (FAIL)]]',
#         'query': ['tiger', 'visits', 'tiger', False],
#         'text': 'The tiger does not visit the tiger?'},
#  'Q8': {'answer': 'CWA',
#         'proofs': '[@0: The bald eagle eats the bald eagle.[CWA. Example of '
#                   'deepest failure = (FAIL)]]',
#         'query': ['bald eagle', 'eats', 'bald eagle', True],
#         'text': 'The bald eagle eats the bald eagle?'},
#  'Q9': {'answer': 'CWA',
#         'proofs': '[@0: The bald eagle is young.[CWA. Example of deepest '
#                   'failure = (FAIL)]]',
#         'query': ['bald eagle', 'is', 'young', False],
#         'text': 'The bald eagle is not young?'}}

# %% [markdown]
# As you can see, each logical world consists of a list of **rules**, and a list of **questions**.
#
# Each rule consists of a **consequent**, which is true only if its **antecedents** are true.  Both the antecedents and the consequent are **propositions**.  If there are no antecedents, then the consequent is always true.  The **text** of the rule is provided only to help you understand the formal **proposition** notation; no part of the MP will ever use the text for any other reason.
#
# Each question consists of a **query**, which is a proposition that may or may not be true in this world.  If a query is not provably true, then it is considered to be false (the so-called <a href="https://en.wikipedia.org/wiki/Closed-world_assumption">closed-world assumption</a>.)
#
# In our notation, a **proposition** is a list of length 4 consisting of a **head** (the subject of the verb), a **predicate** (usually a verb), a **tail** (the object of the verb), and a **negation indicator**.  The negation indicator specifies whether the sentence "head predicate tail" should be considered True or False.

# %% [markdown]
# <a id='section2'></a>

# %% [markdown]
# ## Standardizing Variables

# %% [markdown]
# Notice that many of the rules we just loaded include the generic variable **something**.  Consider these rules for example:
#
# ```
# 'rule1': {'antecedents': [['something', 'needs', 'bald eagle', True],
#                           ['something', 'is', 'cold', False]],
#           'consequent': ['something', 'visits', 'bald eagle', True],
#           'text': 'If something needs the bald eagle and it is not cold then '
#                   'it visits the bald eagle.'},
# 'rule2': {'antecedents': [['something', 'is', 'nice', True],
#                           ['something', 'eats', 'squirrel', False]],
#           'consequent': ['squirrel', 'eats', 'bald eagle', True],
#           'text': 'If something is nice and it does not eat the squirrel then '
#                   'the squirrel eats the bald eagle.'},
# ```
#
# In logical notation, we could write these rules as
#
# $$\forall x:\text{needs}(x,\text{bald eagle})\wedge\neg\text{is}(x,\text{cold})\Rightarrow\text{visits}(x,\text{bald eagle})$$
# $$\forall x:\text{is}(x,\text{nice})\wedge\neg\text{eats}(x,\text{squirrel})\Rightarrow\text{eats}(\text{squirrel},\text{bald eagle})$$
#
# In our corpus, the only variable you will ever see is the word **something**.  Notice the following points:
#
# * If the word **something** occurs in both the antecedents and the consequent of a rule, then it must be the same something.  In other words, you need to bind those two **somethings** to the same term.
# * If the word **something** occurs in two different rules, then those two **somethings** could refer to different things.  They don't need to refer to the same term.
#
# In order to make it clear that the **somethings** in different rules refer to possibly different objects, the first thing we need to do is to standardize variables.  This is your first task.

# %% [markdown]
# At this point, we'll load the file `submitted.py`.
#
# The file `submitted.py` is the only part of your work that the autograder will see. The only purpose of this notebook is to help you debug `submitted.py`.  Once you have revised `submitted.py` enough to make this notebook work, then you should go to the command line, and type `python grade.py`.  Once that command returns without errors, then  you can go ahead and submit your file `submitted.py` to the autograder.  You can submit to the autograder as often as you want, but it will save you trouble if you debug as much as you can on your local machine, before you submit to the autograder.
#
# We will use `importlib` in order to reload your `submitted.py` over and over again.  That way, every time you make a modification in `submitted.py`, you can just re-run  the corresponding block of this notebook, and it will reload `submitted.py` with your modified code.
#
# Since the file is called `submitted.py`, python considers it to contain a module called `submitted`.  As shown, you can read the module's docstring by printing `submitted.__doc__`.  You can also type `help(submitted)` to get a lot of information about the module, including its docstring, a list of all the functions it defines, and all of their docstrings.  For  more about docstrings, see, for example, https://www.python.org/dev/peps/pep-0257/.

# %%
import submitted
import importlib
importlib.reload(submitted)
print(submitted.__doc__)
# Out:
# This is the module you'll submit to the autograder.
#
# There are several function definitions, here, that raise RuntimeErrors.  You should replace
# each "raise RuntimeError" line with a line that performs the function specified in the
# function's docstring.

# %% [markdown]
# Now it's time for you to open `submitted.py`, and start editing it.  You can open it in another Jupyter window by choosing "Open from Path" from the "File" menu, and then typing `submitted.py`.  Alternatively, you can use any text editor.
#
# Once you have it open, try editing the function `standardize_variables` so that its functionality matches its docstring.  Here is what it's docstring says:

# %%
importlib.reload(submitted)
help(submitted.standardize_variables)
# Out:
# Help on function standardize_variables in module submitted:
#
# standardize_variables(nonstandard_rules)
#     @param nonstandard_rules (dict) - dict from ruleIDs to rules
#         Each rule is a dict:
#         rule['antecedents'] contains the rule antecedents (a list of propositions)
#         rule['consequent'] contains the rule consequent (a proposition).
#
#     @return standardized_rules (dict) - an exact copy of nonstandard_rules,
#         except that the antecedents and consequent of every rule have been changed
#         to replace the word "something" with some variable name that is
#         unique to the rule, and not shared by any other rule.
#     @return variables (list) - a list of the variable names that were created.
#         This list should contain only the variables that were used in rules.

# %% [markdown]
# Edit `standardize_variables` so that it does the task specified in its docstring.  When you get the code working, check to make sure that `standardize_variables(worlds[0]['rules'])` works.
#
# Note: your version of `standardize_variables` does **not** need to produce the same variable names as those shown here.  You just need to make sure that (1) in any given rule, there is only one unique variable name, (2) no two rules have instances of the same variable name.

# %%
import pprint
import copy, importlib
importlib.reload(submitted)
worlds = {}
for id in data_worlds.keys():
    worlds[id] = copy.deepcopy(data_worlds[id])
    rules, variables = submitted.standardize_variables(data_worlds[id]['rules'])
    worlds[id]['variables'] = variables
    worlds[id]['rules'] = rules
    
id = 'RelNoneg-D2-2133'
print('The variables for world %s are:'%(id))
print(worlds[id]['variables'])
print("")
print("... and the standardized rules are:")
pprint.PrettyPrinter(indent=1).pprint(worlds[id]['rules'])
# Out:
# The variables for world RelNoneg-D2-2133 are:
# ['x0000', 'x0001', 'x0002']
#
# ... and the standardized rules are:
# {'rule1': {'antecedents': [['x0000', 'eats', 'tiger', True]],
#            'consequent': ['x0000', 'sees', 'tiger', True],
#            'text': 'If something eats the tiger then it sees the tiger.'},
#  'rule2': {'antecedents': [['x0001', 'visits', 'bald eagle', True]],
#            'consequent': ['x0001', 'eats', 'tiger', True],
#            'text': 'If something visits the bald eagle then it eats the '
#                    'tiger.'},
#  'rule3': {'antecedents': [['x0002', 'is', 'rough', True]],
#            'consequent': ['x0002', 'eats', 'tiger', True],
#            'text': 'If something is rough then it eats the tiger.'},
#  'triple1': {'antecedents': [],
#              'consequent': ['bald eagle', 'eats', 'tiger', True],
#              'text': 'The bald eagle eats the tiger.'},
#  'triple10': {'antecedents': [],
#               'consequent': ['tiger', 'is', 'green', True],
#               'text': 'The tiger is green.'},
#  'triple11': {'antecedents': [],
#               'consequent': ['tiger', 'is', 'kind', True],
#               'text': 'The tiger is kind.'},
#  'triple12': {'antecedents': [],
#               'consequent': ['tiger', 'is', 'rough', True],
#               'text': 'The tiger is rough.'},
#  'triple13': {'antecedents': [],
#               'consequent': ['tiger', 'is', 'young', True],
#               'text': 'The tiger is young.'},
#  'triple14': {'antecedents': [],
#               'consequent': ['tiger', 'sees', 'bald eagle', True],
#               'text': 'The tiger sees the bald eagle.'},
#  'triple15': {'antecedents': [],
#               'consequent': ['tiger', 'visits', 'bald eagle', True],
#               'text': 'The tiger visits the bald eagle.'},
#  'triple2': {'antecedents': [],
#              'consequent': ['bald eagle', 'is', 'blue', True],
#              'text': 'The bald eagle is blue.'},
#  'triple3': {'antecedents': [],
#              'consequent': ['bald eagle', 'is', 'green', True],
#              'text': 'The bald eagle is green.'},
#  'triple4': {'antecedents': [],
#              'consequent': ['bald eagle', 'is', 'kind', True],
#              'text': 'The bald eagle is kind.'},
#  'triple5': {'antecedents': [],
#              'consequent': ['bald eagle', 'is', 'rough', True],
#              'text': 'The bald eagle is rough.'},
#  'triple6': {'antecedents': [],
#              'consequent': ['bald eagle', 'sees', 'tiger', True],
#              'text': 'The bald eagle sees the tiger.'},
#  'triple7': {'antecedents': [],
#              'consequent': ['bald eagle', 'visits', 'tiger', True],
#              'text': 'The bald eagle visits the tiger.'},
#  'triple8': {'antecedents': [],
#              'consequent': ['tiger', 'eats', 'bald eagle', True],
#              'text': 'The tiger eats the bald eagle.'},
#  'triple9': {'antecedents': [],
#              'consequent': ['tiger', 'is', 'blue', True],
#              'text': 'The tiger is blue.'}}

# %% [markdown]
# The autograder checks to make sure that your standardized rules are identical to the input rules except that (1) in any given rule, there is only one unique variable name, (2) no two rules have instances of the same variable name.
#
# You can test it by running `grade.py`, and looking at the output for `test_standardization`:

# %%
# !python grade.py --json
# Out:
# Traceback (most recent call last):
#   File "/Users/aahanthapliyal/Desktop/CS440/mp07/grade.py", line 8, in <module>
#     from gradescope_utils.autograder_utils.json_test_runner import JSONTestRunner
# ModuleNotFoundError: No module named 'gradescope_utils'

# %% [markdown]
# <a id='section3'></a>

# %% [markdown]
# ## Unification

# %% [markdown]
# Unification tests two propositions, a `query` and a `datum`, to see whether there is any third proposition (the `unification`) that would imply both.  For example, consider these two propositions:
#
# $$A: \exists x: \text{visits}(x,\text{bald eagle})$$
# $$B: \exists x: \text{visits}(\text{squirrel},x)$$
#
# These two propositions are both satisfied by the claim that squirrel visits bald eagle.  The unification of these two propositions is
#
# $$C: \text{visits}(\text{squirrel},\text{bald eagle})$$
#
# Notice the direction of implicature.  Unification means that $C\Rightarrow A$ and $C\Rightarrow B$.  The opposite is not true: $A\wedge B\not\Rightarrow C$!
#
#
# If a pair of propositions cannot be unified, then the `unify` function should just return `None`, to indicate that no unification is possible.  For example, proposition $A$ says that something visits the bald eagle, but suppose we want to test whether or not there is something that does **not** visit the bald eagle:
#
# $$D: \exists x: \neg\text{visits}(x,\text{bald eagle})$$
#
# The unification of statements $D$ and $B$ is `None`, because there is no single proposition we could provide that would prove both $D$ and $B$.
#
# It is possible to unify two statements without resolving all variables.  For example, consider:
#
# $$E: \exists y,z: \text{visits}(y,z)$$
#
# The unification of statements $A$ and $E$ is:
#
# $$F: \exists y:\text{visits}(y,\text{bald eagle})$$
#
# Statement $F$ has exactly the same meaning as statement $A$.  Nevertheless, it is a valid unification of statements $A$ and $E$: notice that $F\Rightarrow A$ and $F\Rightarrow E$, so we know that the statements are equivalent in that very precise sense.

# %%
importlib.reload(submitted)
help(submitted.unify)
# Out:
# Help on function unify in module submitted:
#
# unify(query, datum, variables)
#     @param query: proposition that you're trying to match.
#       The input query should not be modified by this function; consider deepcopy.
#     @param datum: proposition against which you're trying to match the query.
#       The input datum should not be modified by this function; consider deepcopy.
#     @param variables: list of strings that should be considered variables.
#       All other strings should be considered constants.
#
#     Unification succeeds if (1) every variable x in the unified query is replaced by a
#     variable or constant from datum, which we call subs[x], and (2) for any variable y
#     in datum that matches to a constant in query, which we call subs[y], then every
#     instance of y in the unified query should be replaced by subs[y].
#
#     @return unification (list): unified query, or None if unification fails.
#     @return subs (dict): mapping from variables to values, or None if unification fails.
#        If unification is possible, then answer already has all copies of x replaced by
#        subs[x], thus the only reason to return subs is to help the calling function
#        to update other rules so that they obey the same substitutions.
#
#     Examples:
#
#     unify(['x', 'eats', 'y', False], ['a', 'eats', 'b', False], ['x','y','a','b'])
#       unification = [ 'a', 'eats', 'b', False ]
#       subs = { "x":"a", "y":"b" }
#     unify(['bobcat','eats','y',True],['a','eats','squirrel',True], ['x','y','a','b'])
#       unification = ['bobcat','eats','squirrel',True]
#       subs = { 'a':'bobcat', 'y':'squirrel' }
#     unify(['x','eats','x',True],['a','eats','a',True],['x','y','a','b'])
#       unification = ['a','eats','a',True]
#       subs = { 'x':'a' }
#     unify(['x','eats','x',True],['a','eats','bobcat',True],['x','y','a','b'])
#       unification = ['bobcat','eats','bobcat',True],
#       subs = {'x':'a', 'a':'bobcat'}
#       When the 'x':'a' substitution is detected, the query is changed to
#       ['a','eats','a',True].  Then, later, when the 'a':'bobcat' substitution is
#       detected, the query is changed to ['bobcat','eats','bobcat',True], which
#       is the value returned as the answer.
#     unify(['a','eats','bobcat',True],['x','eats','x',True],['x','y','a','b'])
#       unification = ['bobcat','eats','bobcat',True],
#       subs = {'a':'x', 'x':'bobcat'}
#       When the 'a':'x' substitution is detected, the query is changed to
#       ['x','eats','bobcat',True].  Then, later, when the 'x':'bobcat' substitution
#       is detected, the query is changed to ['bobcat','eats','bobcat',True], which is
#       the value returned as the answer.
#     unify([...,True],[...,False],[...]) should always return None, None, regardless of the
#       rest of the contents of the query or datum.

# %% [markdown]
# Modify the `unify` function so that it performs as specified by the docstring.  Once you have modified it, you can test it with some of the examples provided in the docstring:

# %%
importlib.reload(submitted)
unification, subs = submitted.unify(['x','eats','y',False],['a','eats','b',False],['x','y','a','b'])
print('Unification is:',unification)
print('Subs is:',subs)
# Out:
# Unification is: ['a', 'eats', 'b', False]
# Subs is: {'x': 'a', 'y': 'b'}

# %%
importlib.reload(submitted)
unification, subs = submitted.unify(['bobcat','eats','y',True],['a','eats','squirrel',True],['x','y','a','b'])
print('Unification is:',unification)
print('Subs is:',subs)
# Out:
# Unification is: ['bobcat', 'eats', 'squirrel', True]
# Subs is: {'a': 'bobcat', 'y': 'squirrel'}

# %%
importlib.reload(submitted)
unification, subs = submitted.unify(['x','eats','x',True],['a','eats','bobcat',True],['x','y','a','b'])
print('Unification is:',unification)
print('Subs is:',subs)
# Out:
# Unification is: ['bobcat', 'eats', 'bobcat', True]
# Subs is: {'x': 'a', 'a': 'bobcat'}

# %%
importlib.reload(submitted)
unification, subs = submitted.unify(['a','eats','bobcat',True],['x','eats','x',True],['x','y','a','b'])
print('Unification is:',unification)
print('Subs is:',subs)
# Out:
# Unification is: ['bobcat', 'eats', 'bobcat', True]
# Subs is: {'a': 'x', 'x': 'bobcat'}

# %%
importlib.reload(submitted)
unification, subs = submitted.unify(['a','eats','bobcat',True],['x','eats','x',False],['x','y','a','b'])
print('Unification is:',unification)
print('Subs is:',subs)
# Out:
# Unification is: None
# Subs is: None

# %% [markdown]
# <a id='section4'></a>

# %% [markdown]
# ## Rule Application

# %% [markdown]
# In this MP we will be implementing backward-chaining.  When we apply a rule, therefore, we will apply it backward.  Suppose we have a set of propositions that we are trying to prove; call those the `goals`.  We test whether or not a rule is useful to us by the following procedure:
#
# 1. Test to see whether the consequent of the rule can be unified with a goal, i.e., is there any proposition that, if it were true, would imply both the rule consequent and the goal?
# 1. Take the variable substitutions from the rule application, and modify the rule antecedents using those same substitutions.  Now we have a set of rule antecedent propositions that, if true, would imply the goal.
# 1. Replace the old goal with the new goals that were created by this process.
#
# For example, suppose we have the following rule:
#
# $$\forall x: \text{is}(\text{squirrel},\text{nice})\wedge\text{is}(x,\text{cold})\Rightarrow\text{visits}(x,\text{squirrel})$$
#
# Suppose that we are trying to prove the following list of goal statements:
#
# $$\text{goals}[0]=\text{visits}(\text{bobcat},\text{bald eagle})$$
# $$\text{goals}[1]=\text{visits}(\text{bobcat},\text{squirrel})$$
#
# We can't apply the rule to $\text{goals}[0]$, because the rule talks about visiting squirrel.  We can apply the rule to goal $\text{goals}[1]$, however.  Once we have completed that application, the list of goals now reads:
#
# $$\text{newgoals}[0]=\text{visits}(\text{bobcat},\text{bald eagle})$$
# $$\text{newgoals}[1]=\text{is}(\text{squirrel},\text{nice})$$
# $$\text{newgoals}[2]=\text{is}(\text{bobcat},\text{cold})$$
#
# If we can find a way to prove `newgoals`, that will constitute a proof of `goals`.

# %%
importlib.reload(submitted)
help(submitted.apply)
# Out:
# Help on function apply in module submitted:
#
# apply(rule, goals, variables)
#     @param rule: A rule that is being tested to see if it can be applied
#       This function should not modify rule; consider deepcopy.
#     @param goals: A list of propositions against which the rule's consequent will be tested
#       This function should not modify goals; consider deepcopy.
#     @param variables: list of strings that should be treated as variables
#
#     Rule application succeeds if the rule's consequent can be unified with any one of the goals.
#
#     @return applications: a list, possibly empty, of the rule applications that
#        are possible against the present set of goals.
#        Each rule application is a copy of the rule, but with both the antecedents
#        and the consequent modified using the variable substitutions that were
#        necessary to unify it to one of the goals. Note that this might require
#        multiple sequential substitutions, e.g., converting ('x','eats','squirrel',False)
#        based on subs=={'x':'a', 'a':'bobcat'} yields ('bobcat','eats','squirrel',False).
#        The length of the applications list is 0 <= len(applications) <= len(goals).
#        If every one of the goals can be unified with the rule consequent, then
#        len(applications)==len(goals); if none of them can, then len(applications)=0.
#     @return goalsets: a list of lists of new goals, where len(newgoals)==len(applications).
#        goalsets[i] is a copy of goals (a list) in which the goal that unified with
#        applications[i]['consequent'] has been removed, and replaced by
#        the members of applications[i]['antecedents'].
#
#     Example:
#     rule={
#       'antecedents':[['x','is','nice',True],['x','is','hungry',False]],
#       'consequent':['x','eats','squirrel',False]
#     }
#     goals=[
#       ['bobcat','eats','squirrel',False],
#       ['bobcat','visits','squirrel',True],
#       ['bald eagle','eats','squirrel',False]
#     ]
#     variables=['x','y','a','b']
#
#     applications, newgoals = submitted.apply(rule, goals, variables)
#
#     applications==[
#       {
#         'antecedents':[['bobcat','is','nice',True],['bobcat','is','hungry',False]],
#         'consequent':['bobcat','eats','squirrel',False]
#       },
#       {
#         'antecedents':[['bald eagle','is','nice',True],['bald eagle','is','hungry',False]],
#         'consequent':['bald eagle','eats','squirrel',False]
#       }
#     ]
#     newgoals==[
#       [
#         ['bobcat','visits','squirrel',True],
#         ['bald eagle','eats','squirrel',False]
#         ['bobcat','is','nice',True],
#         ['bobcat','is','hungry',False]
#       ],[
#         ['bobcat','eats','squirrel',False]
#         ['bobcat','visits','squirrel',True],
#         ['bald eagle','is','nice',True],
#         ['bald eagle','is','hungry',False]
#       ]

# %% [markdown]
# Edit your copy of `apply`, and then test it using the example from the docstring:

# %%
import pprint
importlib.reload(submitted)

rule={
      'antecedents':[['x','is','nice',True],['x','is','hungry',False]],
      'consequent':['x','eats','squirrel',False]
}
goals=[
      ['bobcat','eats','squirrel',False],
      ['bobcat','visits','squirrel',True],
      ['bald eagle','eats','squirrel',False]
]
variables=['x','y','a','b']

applications, goalsets = submitted.apply(rule, goals, variables)

print('The possible applications of this rule are:')
pprint.PrettyPrinter(indent=1).pprint(applications)
print('The resulting modified goalsets are:')
pprint.PrettyPrinter(indent=1).pprint(goalsets)
# Out:
# The possible applications of this rule are:
# [{'antecedents': [['bobcat', 'is', 'nice', True],
#                   ['bobcat', 'is', 'hungry', False]],
#   'consequent': ['bobcat', 'eats', 'squirrel', False]},
#  {'antecedents': [['bald eagle', 'is', 'nice', True],
#                   ['bald eagle', 'is', 'hungry', False]],
#   'consequent': ['bald eagle', 'eats', 'squirrel', False]}]
# The resulting modified goalsets are:
# [[['bobcat', 'visits', 'squirrel', True],
#   ['bald eagle', 'eats', 'squirrel', False],
#   ['bobcat', 'is', 'nice', True],
#   ['bobcat', 'is', 'hungry', False]],
#  [['bobcat', 'eats', 'squirrel', False],
#   ['bobcat', 'visits', 'squirrel', True],
#   ['bald eagle', 'is', 'nice', True],
#   ['bald eagle', 'is', 'hungry', False]]]

# %% [markdown]
# <a id='section5'></a>

# %% [markdown]
# ## Backward Chaining

# %% [markdown]
# Backward-chaining is the method of proving a goal statement by finding rules that could be applied in order to prove it.
#
# Backward-chaining is a search algorithm:
# * The **starting state** is the statement that you are trying to prove.
# * Every **action** is a rule application.  The result of an action is to create a new goalset.
# * Every **state** is a goalset.  A goalset is a list of propositions called "goals" such that, if every goal is proven true, then that constitutes a proof of the statement you are trying to prove.
# * The **ending state** is an empty goalset.  The ending state is achieved by transforming the starting state into a list of goals such that every goal in that list is a known true proposition, i.e., the consequent of a rule that has an empty antecedents list.
#
# In backward-chaining, it is possible that your frontier will empty out before you ever reach a goal state.  If that happens, it means that it is impossible to prove the query based on the propositions that are known in this world.  Because of our <a href="https://en.wikipedia.org/wiki/Closed-world_assumption">closed-world assumption</a>, we pretend that our inability to prove the query is proof of its falsehood, so in that case, your `backward_chain` method should return the value `proof==None`.

# %%
importlib.reload(submitted)
help(submitted.backward_chain)
# Out:
# Help on function backward_chain in module submitted:
#
# backward_chain(query, rules, variables)
#     @param query: a proposition, you want to know if it is true
#     @param rules: dict mapping from ruleIDs to rules
#     @param variables: list of strings that should be treated as variables
#
#     @return proof (list): a list of rule applications
#       that, when read in sequence, conclude by proving the truth of the query.
#       If no proof of the query was found, you should return proof=None.

# %% [markdown]
# The goal of this part of the MP is just to come up with an algorithm that can correctly distinguish between questions in which `worlds[i]['questions'][j]['answer']==True` and those in which `worlds[i]['questions'][j]['answer']==False`.  You should feel pretty free to implement this in whatever way you like, e.g., you can use BFS or A* search, you can choose to re-expand previously expanded nodes or not, your frontier can use tuples or you can define a Node class for the frontier, and so on.  The key is just to get the right answers.

# %%
import pprint
importlib.reload(submitted)
world = worlds['RelNoneg-D2-2133']
question = world['questions']['Q3']
print(question['text'])
print('Reference answer is:',question['answer'])
print('Reference proof is:',question['proofs'])
proof = submitted.backward_chain(question['query'],world['rules'], world['variables'])
if proof==None:
    print('My code says the answer is: False')
else:
    print('My code says the answer is: True')
    pprint.PrettyPrinter(indent=1).pprint(proof)
# Out:
# The tiger eats the tiger?
# Reference answer is: True
# Reference proof is: [(((triple12) -> rule3) OR ((triple15) -> rule2))]
# My code says the answer is: False

# %% [markdown]
# You will be graded only on the questions whose answers are either `True` or `False`.  The questions whose answers are `NAF` or `CWA` are considered to be technically true, under the closed-world assumption, but the methods for proving their truth are beyond the scope of this MP.

# %%
importlib.reload(submitted)
world = worlds['RelNoneg-D2-2133']
for (qid, question) in world['questions'].items():
    if question['answer']==True or question['answer']==False:
        print(qid, ": ",question['text'])
        print("   Reference proof is:",question['proofs'])
        print('   Reference answer is:',question['answer'])
        proof = submitted.backward_chain(question['query'],world['rules'],world['variables'])
        if proof==None:
            print('    My code says the answer is: False')
        else:
            print('    My code says the answer is: True')
            pprint.pp(proof,indent=1)
# Out:
# Q1 :  The tiger is blue?
#    Reference proof is: [(triple9)]
#    Reference answer is: True
#     My code says the answer is: True
# [['tiger', 'is', 'blue', True]]
# Q2 :  The tiger is not rough?
#    Reference proof is: [(triple12)]
#    Reference answer is: False
#     My code says the answer is: False
# Q3 :  The tiger eats the tiger?
#    Reference proof is: [(((triple12) -> rule3) OR ((triple15) -> rule2))]
#    Reference answer is: True
#     My code says the answer is: False
# Q4 :  The tiger does not eat the tiger?
#    Reference proof is: [(((triple12) -> rule3) OR ((triple15) -> rule2))]
#    Reference answer is: False
#     My code says the answer is: False
# Q5 :  The tiger sees the tiger?
#    Reference proof is: [(((((triple12) -> rule3)) -> rule1) OR ((((triple15) -> rule2)) -> rule1))]
#    Reference answer is: True
#     My code says the answer is: False
# Q6 :  The tiger does not see the tiger?
#    Reference proof is: [(((((triple12) -> rule3)) -> rule1) OR ((((triple15) -> rule2)) -> rule1))]
#    Reference answer is: False
#     My code says the answer is: False

# %% [markdown]
# <a id='grade'></a>

# %% [markdown]
# ## Grade your homework

# %% [markdown]
# If you've reached this point, and all of the above sections work, then you're ready to try grading your homework!  Before you submit it to Gradescope, try grading it on your own machine.  This will run some visible test cases (which you can read in `tests/test_visible.py`), and compare the results to the solutions (which you can read in `solution.json`).
#
# The exclamation point (!) tells python to run the following as a shell command.  Obviously you don't need to run the code this way -- this usage is here just to remind you that you can also, if you wish, run this command in a terminal window.

# %%
# !python grade.py
# Out:
# ....
# ----------------------------------------------------------------------
# Ran 4 tests in 0.004s
#
# OK

# %% [markdown]
# If you got any 'E' marks, it means that your code generated some runtime errors, and you need to debug those.
#
# If you got any 'F' marks, it means that your code ran without errors, but that it generated results that did not pass the test assertions listed in `tests/test_visible.py`.  Try debugging those.
#
# If neither of those things happened, and your result was a series of dots, then your code works perfectly.
#
# If you're not sure, you can try running grade.py with the -j option.  This will produce a JSON results file, in which the best score you can get is 50.

# %%
# !python grade.py -j
# Out:
# {
#     "tests": [
#         {
#             "name": "test_apply (test_visible.TestStep)",
#             "score": 12.5,
#             "max_score": 12.5
#         },
#         {
#             "name": "test_backward_chain (test_visible.TestStep)",
#             "score": 12.5,
#             "max_score": 12.5
#         },
#         {
#             "name": "test_standardization (test_visible.TestStep)",
#             "score": 12.5,
#             "max_score": 12.5
#         },
#         {
#             "name": "test_unify (test_visible.TestStep)",
#             "score": 12.5,
#             "max_score": 12.5
#         }
#     ],
#     "leaderboard": [],
#     "visibility": "visible",
#     "execution_time": "0.01",
#     "score": 50.0
# }

# %% [markdown]
# Now you should try uploading `submitted.py` to <a href="https://www.gradescope.com/courses/486387">Gradescope</a>.
#
# Gradescope will run the same visible tests that you just ran on your own machine, plus some additional hidden tests.  It's possible that your code passes all the visible tests, but fails the hidden tests.  If that happens, then it probably means that you hard-coded a number into your function definition, instead of using the input parameter that you were supposed to use.  Debug by running your function with a variety of different input parameters, and see if you can get it to respond correctly in all cases.
#
# Once your code works perfectly on Gradescope, with no errors, then you are done with the MP.  Congratulations!
